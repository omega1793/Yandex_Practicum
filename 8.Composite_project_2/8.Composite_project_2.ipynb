# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
#
# <h2> Итоговый комментарий ревьюера 2 (итоговый вывод по проекту) <a class="tocSkip"> </h2>
#
#
#
# Теперь почти идеально. Принимаю работу)
#
# Если хочешь лучше разобраться в ML, то могу посоветовать тебе:
#
# - Открытый курс машинного обучения: https://habr.com/ru/company/ods/blog/322626/
#
# - Книжка от ШАД: https://academy.yandex.ru/handbook/ml/
#
# - Также рекомендую лекции от Andrew Ng: https://www.youtube.com/watch?v=PPLop4L2eGk&list=PLLssT5z_DsK-h9vYZkQkYNWcItqhlRJLN
# - Избежать утечки данных при кросс-валидации тебе поможет <a href="https://towardsdatascience.com/pipeline-columntransformer-and-featureunion-explained-f5491f815f">конвеерная обработка данных</a>.
#
# - Не все признаки приносят пользу при моделировании. Инструмент <a href="https://proglib.io/p/feature-selector">FeatureSelector</a> поможет тебе отобрать важные признаки и избавит от ручной обработки.  Также можешь посмотреть статью на <a href="https://www.kaggle.com/code/prashant111/comprehensive-guide-on-feature-selection/notebook">Kaggle</a> (она сложнее).
#
#
# В этом проекте были отработаны все моменты.
#
# Успехов тебе в следующем спринте!
#
# Рад был помочь тебе)
#
# **Буду очень благодарен, если ты поставишь мне положительную оценку за проект в форме на странице курса, это важно для меня. Достаточно поставить оценку, а комментарий можешь написать по желанию:)**
#
# </div>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# Привет, меня зовут Александр Куимов. Я буду ревьюером твоего проекта. Ты можешь обращаться ко мне на "ты"😏 Надеюсь, тебя также не смутит, если я буду обращаться к тебе на "ты", но если это неудобно, обязательно скажи об этом!
#
# **Пожалуйста, не перемещай, не изменяй и не удаляй мои комментарии**, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Прошу реагировать на все мои комментарии, по которым ты вносишь правки в проект, своими комментариями по шаблону, показанному чуть ниже. На каждое мое замечание нужно отвечать комментарием студента в маркдаун ячейке **ниже моей. Это нужно, чтобы не создавалась путаница**.😉
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В случае, если решение на отдельном шаге является полностью правильным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> В случае, когда решение на отдельном шаге станет еще лучше, если внести небольшие коррективы.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#  В случае, когда решение на отдельном шаге требует существенной переработки и внесения правок. Напоминаю, что проект не может быть принят с первого раза, если ревью содержит комментарии, рекомендующие доработать шаги.
# </div>
#
#
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>👋:</b> В такой цветовой ячейке - образце я прошу тебя оставлять твои комментарии. **Обязательно добавь заголовок "Комментарий студента" к каждой твоей ячейке**. Если исправляешь проект во второй раз и далее, не забывай пожалуйста указывать номер итерации, например, "Комментарий студента v.2". У меня к этому моменту уже появится нумерация в моих комментариях.
# </div>
#
# <br/>
#
# Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие и дам тебе возможность самому найти и исправить ее. На реальной работе твой руководитель будет поступать также, и я пытаюсь подготовить тебя именно к работе датасаентистом. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку!🤓
#
#    **Если у тебя будут возникают какие-то сложности, связанные с выполнением этого проекта**, то я смогу отвечать тебе на вопросы только в ходе ревью до 24 часов на основании соглашения об уровне услуг SLA (это может быть любое время суток, даже ночью), и к сожалению, каждые из таких ревью расходуют доступные иттерации (их всего 6).
# Лучшее решение в подобных случаях - обратиться за помощью к преподавателю по проектам в треде для получения оперативных консультаций. На всякий случай акцентирую, что преподаватель отвечает в тредах, а в личку не отвечает. В редких случаях может возникнуть ситуация, когда преподаватель не ответил вовремя, в таком случае рекомендую связаться с куратором для оперативного решения вопроса.
#
#    **Если у тебя будут возникают вопросы, которые не касаются проекта и моих комментариев в нем**, а касаются теории и спринта, то я смогу кратко тебе ответить, а подробнее на вопрос тебе ответит преподаватель и по запросу сможет подобрать материал адекватный текущему прогрессу курса (только нужно написать ему в тред) 🤓

# %% [markdown]
# # Проект: HR-аналитика

# %% [markdown]
# **Задачи проекта**:
# 1. Построить модель, которая сможет предсказать уровень удовлетворённости сотрудника на основе данных заказчика.
# 2. Построить модель, которая сможет на основе данных заказчика предсказать то, что сотрудник уволится из компании.
#
# В распоряжении 5 датасетов:
# * *`train_job_satisfaction_rate.csv`* - Тренировочная выборка первой задачи.
# * *`train_quit.csv`* - Тренировочная выборка второй задачи.
# * *`test_features.csv`* - Входные признаки тестовой выборки обеих задач.
# * *`test_target_job_satisfaction_rate.csv`* - Целевой признак тестовой выборки первой задачи.
# * *`test_target_quit.csv`* - Целевой признак тестовой выборки второй задачи.
#
# Описание даных:
# * *`id`* — уникальный идентификатор сотрудника.
# * *`dept`* — отдел, в котором работает сотрудник
# * *`level`* — уровень занимаемой должности.
# * *`workload`* — уровень загруженности сотрудника.
# * *`employment_years`* — длительность работы в компании (в годах).
# * *`last_year_promo`* — показывает, было ли повышение за последний год.
# * *`last_year_violations`* — показывает, нарушал ли сотрудник трудовой договор за последний год.
# * *`supervisor_evaluation`* — оценка качества работы сотрудника, которую дал руководитель.
# * *`salary`* — ежемесячная зарплата сотрудника.
# * *`job_satisfaction_rate`* — уровень удовлетворённости сотрудника работой в компании, целевой признак первой задачи.
# * *`quit`* - увольнение сотрудника из компании, целевой признак второй задачи.
#
#
# Нет информации о качестве данных, потому нужно провести изучение данных до того, как приступать к иcследованию. После изучения данных сделаем предобработку данных, устраняя все возможные ошибки, пропуски и дубликаты данных, чтобы они не искажали результаты работы.

# %%
# Установим отсутствующие библиотеки
# !pip install scikit-learn==1.1.3 -q
# !pip install phik -q

# %%
# Импортируем необходимые библиотеки и инструменты
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import phik

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler, MinMaxScaler, LabelEncoder 
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.metrics import roc_auc_score, make_scorer
from sklearn.model_selection import RandomizedSearchCV
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.svm import SVC
from sklearn.inspection import permutation_importance
from phik.report import plot_correlation_matrix
from phik import report
from scipy import stats as st
from scipy.stats import binom, poisson

# %%
# Установим константу
RANDOM_STATE = 42

# %% [markdown]
# ## Модель предсказания удовлетворённости сотрудника

# %% [markdown]
# Объявим собственные функциим оптимизации процесса работы:

# %%
# Объявляем функцию для изучения всей информации об датафрейме
def df_review(df, name):
    print('Краткое содержание датафрейма', name)
    display(df.head())
    print('='*100)    
    print('Информация о датафрейме', name)
    df.info()
    print('='*100)   
    print('Размер датафрейма', name, ':', df.shape)
    print('='*100)  
    print('Охарактеризация числовых данных датафрейма', name)
    display(df.drop('id', axis=1).describe().T)
    print('='*100)
    print('Количество явных дубликатов в датафрейте', name, ':', df.duplicated().sum())
    print('Количество пропусков в датафрейте', name, ':', '\n', df.isna().sum())

# %%
# Объявляем функцию для изучения всей информации о столбце
def col_review(df, column):
    print('Размер:', df[column].shape[0])
    print('='*100)
    print('Охарактеризация данных')
    display(df[column].describe().T)
    print('='*100)
    print('Количество уникальных значений:', df[column].unique().shape[0])
    print('Количество пропусков в датафрейте', df[column].isna().sum())
    print('='*100)
    if type(df[column].loc[1]) == str:
        print('Уникальные значения:')
        print(df[column].value_counts())

# %%
# Объявляем функцию для построения гистограммы и "ящика с усами" количественных данных
def hix_box_plot(df, column):
    fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16,6))
    fig.suptitle(f'Обзор данных {column}', fontsize = 20, fontweight='bold')
    df[column].plot(ax=ax[0], kind='hist')
    sns.boxplot(df[column], ax=ax[1])
    ax[0].set_title(f'Гистограмма', fontsize=16)
    ax[0].set_xlabel(column)
    ax[1].set_title(f'Диграмма размаха', fontsize=16)
    ax[1].set_xlabel(column)

# %%
# Объявляем функцию для построения графиков категориальных данных
def bar_pie_plot(df, column):
    fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16,6))
    fig.suptitle(f'Обзор данных {column}', fontsize = 20, fontweight='bold')
    df.groupby(column)[column].count().plot(ax=ax[0], kind='bar') 
    df.groupby(column)[column].count().plot(ax=ax[1], kind='pie', autopct='%1.0f%%')            
    ax[0].set_title(f'Количественная диограмма')
    ax[1].set_title(f'Круговая диограмма')        
    ax[0].tick_params(axis='x', labelrotation=0, labelsize = 15) 
    ax[1].set_ylabel(' ')
    ax[0].set_ylabel('Количество')
    ax[0].set_xlabel('Значения')

# %%
# Объявляем функцию распределения зарплат сотрудников по категориям
def salary_cat(value):
    if value >= 80000:
            return "≥80к"
    elif value < 80000 and value >= 60000:
            return "60-80к"
    elif value < 60000 and value >= 40000:
            return "40-60к"
    elif value < 40000 and value >= 20000:
            return "20-40к"
    elif value < 20000:
            return "≤20к"

# %% [markdown]
# ### Загрузка данных

# %%
# Загружаем данные с возможностью загрузить их с сервера в случае недоступности локальных файлов
try:
    train = pd.read_csv('/datasets/train_job_satisfaction_rate.csv')
    X_test = pd.read_csv('/datasets/test_features.csv')
    y_test = pd.read_csv('/datasets/test_target_job_satisfaction_rate.csv')
except:
    train = pd.read_csv('https://code.s3.yandex.net/datasets/train_job_satisfaction_rate.csv')
    X_test = pd.read_csv('https://code.s3.yandex.net/datasets/test_features.csv')
    y_test = pd.read_csv('https://code.s3.yandex.net/datasets/test_target_job_satisfaction_rate.csv')

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# #### train

# %%
# Обзор датафрейма train
df_review(train, 'train')
# Out:
# Краткое содержание датафрейма train
#        id        dept   level workload  employment_years last_year_promo  \
# 0  155278       sales  junior   medium                 2              no
# 1  653870          hr  junior     high                 2              no
# 2  184592       sales  junior      low                 1              no
# 3  171431  technology  junior      low                 4              no
# 4  693419          hr  junior   medium                 1              no
#
#   last_year_violations  supervisor_evaluation  salary  job_satisfaction_rate
# 0                   no                      1   24000                   0.58
# 1                   no                      5   38400                   0.76
# 2                   no                      2   12000                   0.11
# 3                   no                      2   18000                   0.37
# 4                   no                      3   22800                   0.20
# ...
# Информация о датафрейме train
# ...

# %%
# Проверим некоторые столбцы датафрейма на наличие неявных дубликатов
train['dept'].sort_values().unique()
# Out:
# array(['hr', 'marketing', 'purchasing', 'sales', 'technology', nan],
#       dtype=object)

# %%
train['level'].sort_values().unique()
# Out:
# array(['junior', 'middle', 'sinior', nan], dtype=object)

# %%
train['workload'].sort_values().unique()
# Out:
# array(['high', 'low', 'medium'], dtype=object)

# %% [markdown]
# **Вывод** по *`train`*:
# * Дубликаты не обнаружены;
# * Типы данных верные;
# * Названия столбцов имею "змеиный регистр";
# * Обнаружены пропуски, заполним их во время подготовки данных к построению модели.

# %% [markdown]
# #### X_test

# %%
# Обзор датафрейма X_test
df_review(X_test, 'X_test')
# Out:
# Краткое содержание датафрейма X_test
#        id       dept   level workload  employment_years last_year_promo  \
# 0  485046  marketing  junior   medium                 2              no
# 1  686555         hr  junior   medium                 1              no
# 2  467458      sales  middle      low                 5              no
# 3  418655      sales  middle      low                 6              no
# 4  789145         hr  middle   medium                 5              no
#
#   last_year_violations  supervisor_evaluation  salary
# 0                   no                      5   28800
# 1                   no                      4   30000
# 2                   no                      4   19200
# 3                   no                      4   19200
# 4                   no                      5   40800
# ...
# Информация о датафрейме X_test
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
# ...

# %%
# Проверим некоторые столбцы датафрейма на наличие неявных дубликатов
X_test['dept'].sort_values().unique()
# Out:
# array([' ', 'hr', 'marketing', 'purchasing', 'sales', 'technology', nan],
#       dtype=object)

# %%
X_test['level'].sort_values().unique()
# Out:
# array(['junior', 'middle', 'sinior', nan], dtype=object)

# %%
X_test['workload'].sort_values().unique()
# Out:
# array([' ', 'high', 'low', 'medium'], dtype=object)

# %% [markdown]
# Неявные дубликаты не найдены, однако можно заметить значения в виде пробелов. Заменим их на nan для дальнейшей обработки во время подготовки данных к построения модели.

# %%
X_test['dept'] = X_test['dept'].replace(' ', np.nan)
X_test['workload'] = X_test['workload'].replace(' ', np.nan)

# %%
# Ещё раз проверим уникальные значения столбцов
X_test['dept'].sort_values().unique()
# Out:
# array(['hr', 'marketing', 'purchasing', 'sales', 'technology', nan],
#       dtype=object)

# %%
X_test['workload'].sort_values().unique()
# Out:
# array(['high', 'low', 'medium', nan], dtype=object)

# %% [markdown]
# **Вывод** по *`X_test`*:
# * Дубликаты не обнаружены;
# * Типы данных верные;
# * Названия столбцов имею "змеиный регистр";
# * Обнаружены пропуски, заполним их во время подготовки данных к построению модели.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>
#
# Аномалия обработана корректно. В целом она могла бы быть обработана и в `Pipeline`, при настройке энкодеров на обработку новых значений признаков, которые не были на момент обучения энкодера

# %% [markdown]
# #### y_test

# %%
# Обзор датафрейма y_test
df_review(y_test, 'y_test')
# Out:
# Краткое содержание датафрейма y_test
#        id  job_satisfaction_rate
# 0  130604                   0.74
# 1  825977                   0.75
# 2  418490                   0.60
# 3  555320                   0.72
# 4  826430                   0.08
# ...
# Информация о датафрейме y_test
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   job_satisfaction_rate  2000 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 31.4 KB
# ...
# Размер датафрейма y_test : (2000, 2)
# ...
# Охарактеризация числовых данных датафрейма y_test
#                         count     mean      std   min   25%   50%   75%  max
# job_satisfaction_rate  2000.0  0.54878  0.22011  0.03  0.38  0.58  0.72  1.0
# ...
# Количество явных дубликатов в датафрейте y_test : 0
# ...

# %% [markdown]
# **Вывод** по *`y_test`*:
# * Дубликаты не обнаружены;
# * Типы данных верные;
# * Названия столбцов имею "змеиный регистр";
# * Пропуски не обнаружены.

# %% [markdown]
# #### Вывод по предобработке данных

# %% [markdown]
# * Дубликаты не обнаружены;
# * Типы данных верные;
# * Названия столбцов имею "змеиный регистр";
# * Обнаружены пропуски, заполним их во время подготовки данных к построению модели.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# С данными познакомились, проведен первичный аналитический осмотр!) Полученная информация поможет нам в дальнейшем с предобработкой данных

# %% [markdown]
# ### Исследовательский анализ данных

# %% [markdown]
# Исследовательский анализ данных будем проводить по каждому столбцу всех датафреймов одновременно.

# %% [markdown]
# #### id — уникальный идентификатор сотрудника

# %%
# Количество уникальных значений для датафрейма train
train['id'].unique().shape[0]
# Out:
# 4000

# %%
# Для датафрейма X_test
X_test['id'].unique().shape[0]
# Out:
# 2000

# %% [markdown]
# Все значения id сотрудников уникальны.

# %% [markdown]
# #### dept — отдел, в котором работает сотрудник

# %%
# Общая информация для датафрейма train
col_review(train, 'dept')
# Out:
# Размер: 4000
# ...
# Охарактеризация данных
# count      3994
# unique        5
# top       sales
# freq       1512
# Name: dept, dtype: object
# ...
# Количество уникальных значений: 6
# Количество пропусков в датафрейте 6
# ...
# Уникальные значения:
# sales         1512
# technology     866
# purchasing     610
# marketing      550
# hr             456
# Name: dept, dtype: int64

# %%
# Графики для датафрейма train
bar_pie_plot(train, 'dept')

# %% [markdown]
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# Важно еще поработать над оформлением графика (стандартное правило оформления: должно быть название горизонтальной оси, вертикальной оси и самого графика)
#
#
# *Если вдруг в проекте используются графики `SHAP`, то их это правило касается таким же образом. Так как `SHAP` график тоже является визуальным объектом, для его кастомизации мы можем использовать методы plt, как и для других графиков, однако это потребует небольшой настройки самого объекта `SHAP`. Подробнее можно глянуть тут: https://github.com/shap/shap/issues/594.*
#
#
#
# **Правило по оформлению графиков касается не только текущего графика, а абсолютно всех графиков в проекте: и одиночных, и сгруппированных, и боксплотов, и  SHAP графиков, и прочих объектов визуализации.**

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>👋:</b> Поправил
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %%
# Общая информация для датафрейма X_test
col_review(X_test, 'dept')
# Out:
# Размер: 2000
# ...
# Охарактеризация данных
# count      1997
# unique        5
# top       sales
# freq        763
# Name: dept, dtype: object
# ...
# Количество уникальных значений: 6
# Количество пропусков в датафрейте 3
# ...
# Уникальные значения:
# sales         763
# technology    455
# marketing     279
# purchasing    273
# hr            227
# Name: dept, dtype: int64

# %%
# Графики для датафрейма X_test
bar_pie_plot(X_test, 'dept')

# %% [markdown]
# Данный столбец имеет 5 уникальных значений, одинаковых в тренировочном и тестовом датафреймах. В обоих датафреймах имеются пропуски в данном столбце. Заметен дисбаланс значений.

# %% [markdown]
# #### level — уровень занимаемой должности

# %%
# Общая информация для датафрейма train
col_review(train, 'level')
# Out:
# Размер: 4000
# ...
# Охарактеризация данных
# count       3996
# unique         3
# top       junior
# freq        1894
# Name: level, dtype: object
# ...
# Количество уникальных значений: 4
# Количество пропусков в датафрейте 4
# ...
# Уникальные значения:
# junior    1894
# middle    1744
# sinior     358
# Name: level, dtype: int64

# %%
# Графики для датафрейма train
bar_pie_plot(train, 'level')

# %%
# Общая информация для датафрейма X_test
col_review(X_test, 'level')
# Out:
# Размер: 2000
# ...
# Охарактеризация данных
# count       1999
# unique         3
# top       junior
# freq         974
# Name: level, dtype: object
# ...
# Количество уникальных значений: 4
# Количество пропусков в датафрейте 1
# ...
# Уникальные значения:
# junior    974
# middle    854
# sinior    171
# Name: level, dtype: int64

# %%
# Графики для датафрейма X_test
bar_pie_plot(X_test, 'level')

# %% [markdown]
# Данный столбец имеет 3 уникальных значения, одинаковых в тренировочном и тестовом датафреймах. В обоих датафреймах имеются пропуски в данном столбце. Заметен дисбаланс значений.

# %% [markdown]
# #### workload — уровень загруженности сотрудника

# %%
# Общая информация для датафрейма train
col_review(train, 'workload')
# Out:
# Размер: 4000
# ...
# Охарактеризация данных
# count       4000
# unique         3
# top       medium
# freq        2066
# Name: workload, dtype: object
# ...
# Количество уникальных значений: 3
# Количество пропусков в датафрейте 0
# ...
# Уникальные значения:
# medium    2066
# low       1200
# high       734
# Name: workload, dtype: int64

# %%
# Графики для датафрейма train
bar_pie_plot(train, 'workload')

# %%
# Общая информация для датафрейма X_test
col_review(X_test, 'workload')
# Out:
# Размер: 2000
# ...
# Охарактеризация данных
# count       1999
# unique         3
# top       medium
# freq        1043
# Name: workload, dtype: object
# ...
# Количество уникальных значений: 4
# Количество пропусков в датафрейте 1
# ...
# Уникальные значения:
# medium    1043
# low        593
# high       363
# Name: workload, dtype: int64

# %%
# Графики для датафрейма X_test
bar_pie_plot(X_test, 'workload')

# %% [markdown]
# Данный столбец имеет 3 уникальных значения, одинаковых в тренировочном и тестовом датафреймах. В датафрейме *`X_test`* имеется пропуск в данном столбце. Заметен дисбаланс значений.

# %% [markdown]
# #### employment_years — длительность работы в компании (в годах)

# %%
# Общая информация для датафрейма train
col_review(train, 'employment_years')
# Out:
# Размер: 4000
# ...
# Охарактеризация данных
# count    4000.000000
# mean        3.718500
# std         2.542513
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         6.000000
# max        10.000000
# Name: employment_years, dtype: float64
# ...
# Количество уникальных значений: 10
# Количество пропусков в датафрейте 0
# ...

# %%
# Графики для датафрейма train
bar_pie_plot(train,'employment_years')

# %% [markdown]
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера  <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
#
# Обычные гистограммы для анализа распределения дискретных признаков не подходят: так как `hist` гистограммы делят значения признаков на корзины с числом параметра `bins`, некоторые одинаковы е значения могут падать в разные корзины (это хорошо видно на графиках, когда корзины неравно удалены друг от друга).
#
# Для их анализа нужнен тип графиков, который на каждое уникальные значение признака строит свою корзину. Например, можно использовать `sns.countplot`.
#
# Для этих признаков также не нужно строить ящики с усами, так как признак имеет, скорее, распределение категориального признака, пусть и представленного уже в численном виде.
#
# На всякий случай, `employment_years` и `supervisor_evaluation` - дискретные признаки, хоть и представлены в численном виде.
#
# **это касается анализа и обучающей выборки, и тестовой выборки, как первой, так и второй задачи**

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>👋:</b> Точно. Как то тупанул. На счёт `supervisor_evaluation` сразу были графики для категореальных признаков, а тут исправил.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %%
# Общая информация для датафрейма X_test
col_review(X_test, 'employment_years')
# Out:
# Размер: 2000
# ...
# Охарактеризация данных
# count    2000.000000
# mean        3.666500
# std         2.537222
# min         1.000000
# 25%         1.000000
# 50%         3.000000
# 75%         6.000000
# max        10.000000
# Name: employment_years, dtype: float64
# ...
# Количество уникальных значений: 10
# Количество пропусков в датафрейте 0
# ...

# %%
# Графики для датафрейма X_test
bar_pie_plot(X_test,'employment_years')

# %% [markdown]
# В значениях данного столбца заметен дисбаланс значений. В компании явно работает достаточно много новых сотрудников.

# %% [markdown]
# #### last_year_promo — показывает, было ли повышение за последний год

# %%
# Общая информация для датафрейма train
col_review(train, 'last_year_promo')
# Out:
# Размер: 4000
# ...
# Охарактеризация данных
# count     4000
# unique       2
# top         no
# freq      3880
# Name: last_year_promo, dtype: object
# ...
# Количество уникальных значений: 2
# Количество пропусков в датафрейте 0
# ...
# Уникальные значения:
# no     3880
# yes     120
# Name: last_year_promo, dtype: int64

# %%
# Графики для датафрейма train
bar_pie_plot(train, 'last_year_promo')

# %%
# Общая информация для датафрейма X_test
col_review(X_test, 'last_year_promo')
# Out:
# Размер: 2000
# ...
# Охарактеризация данных
# count     2000
# unique       2
# top         no
# freq      1937
# Name: last_year_promo, dtype: object
# ...
# Количество уникальных значений: 2
# Количество пропусков в датафрейте 0
# ...
# Уникальные значения:
# no     1937
# yes      63
# Name: last_year_promo, dtype: int64

# %%
# Графики для датафрейма X_test
bar_pie_plot(X_test, 'last_year_promo')

# %% [markdown]
# В значениях данного столбца заметен дисбаланс значений. В компании всего около 3% сотрудников получили повышение за последний год.

# %% [markdown]
# #### last_year_violations — показывает, нарушал ли сотрудник трудовой договор за последний год

# %%
# Общая информация для датафрейма train
col_review(train, 'last_year_violations')
# Out:
# Размер: 4000
# ...
# Охарактеризация данных
# count     4000
# unique       2
# top         no
# freq      3441
# Name: last_year_violations, dtype: object
# ...
# Количество уникальных значений: 2
# Количество пропусков в датафрейте 0
# ...
# Уникальные значения:
# no     3441
# yes     559
# Name: last_year_violations, dtype: int64

# %%
# Графики для датафрейма train
bar_pie_plot(train, 'last_year_violations')

# %%
# Общая информация для датафрейма X_test
col_review(X_test, 'last_year_violations')
# Out:
# Размер: 2000
# ...
# Охарактеризация данных
# count     2000
# unique       2
# top         no
# freq      1738
# Name: last_year_violations, dtype: object
# ...
# Количество уникальных значений: 2
# Количество пропусков в датафрейте 0
# ...
# Уникальные значения:
# no     1738
# yes     262
# Name: last_year_violations, dtype: int64

# %%
# Графики для датафрейма X_test
bar_pie_plot(X_test, 'last_year_violations')

# %% [markdown]
# В значениях данного столбца заметен дисбаланс значений. В компании около 14% сотрудников нарушали трудовой договор за последний год.

# %% [markdown]
# #### supervisor_evaluation — оценка качества работы сотрудника, которую дал руководитель

# %%
# Общая информация для датафрейма train
col_review(train, 'supervisor_evaluation')
# Out:
# Размер: 4000
# ...
# Охарактеризация данных
# count    4000.000000
# mean        3.476500
# std         1.008812
# min         1.000000
# 25%         3.000000
# 50%         4.000000
# 75%         4.000000
# max         5.000000
# Name: supervisor_evaluation, dtype: float64
# ...
# Количество уникальных значений: 5
# Количество пропусков в датафрейте 0
# ...

# %%
# Графики для датафрейма train
bar_pie_plot(train, 'supervisor_evaluation')

# %%
# Общая информация для датафрейма X_test
col_review(X_test, 'supervisor_evaluation')
# Out:
# Размер: 2000
# ...
# Охарактеризация данных
# count    2000.000000
# mean        3.526500
# std         0.996892
# min         1.000000
# 25%         3.000000
# 50%         4.000000
# 75%         4.000000
# max         5.000000
# Name: supervisor_evaluation, dtype: float64
# ...
# Количество уникальных значений: 5
# Количество пропусков в датафрейте 0
# ...

# %%
# Графики для датафрейма X_test
bar_pie_plot(X_test, 'supervisor_evaluation')

# %% [markdown]
# В значениях данного столбца заметен дисбаланс значений. В компании около 72% сотрудников имеют хорошую оценку руководителя.

# %% [markdown]
# #### salary — ежемесячная зарплата сотрудника

# %%
# Общая информация для датафрейма train
col_review(train, 'salary')
# Out:
# Размер: 4000
# ...
# Охарактеризация данных
# count     4000.000000
# mean     33926.700000
# std      14900.703838
# min      12000.000000
# 25%      22800.000000
# 50%      30000.000000
# 75%      43200.000000
# max      98400.000000
# Name: salary, dtype: float64
# ...
# Количество уникальных значений: 68
# Количество пропусков в датафрейте 0
# ...

# %%
# Графики для датафрейма train
hix_box_plot(train,'salary')
# Out:
# /opt/conda/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Общая информация для датафрейма X_test
col_review(X_test, 'salary')
# Out:
# Размер: 2000
# ...
# Охарактеризация данных
# count     2000.000000
# mean     34066.800000
# std      15398.436729
# min      12000.000000
# 25%      22800.000000
# 50%      30000.000000
# 75%      43200.000000
# max      96000.000000
# Name: salary, dtype: float64
# ...
# Количество уникальных значений: 66
# Количество пропусков в датафрейте 0
# ...

# %%
# Графики для датафрейма X_test
hix_box_plot(X_test,'salary')
# Out:
# /opt/conda/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# В значениях данного столбца заметны выбросы. Выбросы не аномальны, т.к. такие зарплаты вполне реальны для высококвалифицированных сотрудников.

# %% [markdown]
# #### job_satisfaction_rate — уровень удовлетворённости сотрудника работой в компании, целевой признак первой задачи

# %%
# Общая информация для датафрейма train
col_review(train, 'job_satisfaction_rate')
# Out:
# Размер: 4000
# ...
# Охарактеризация данных
# count    4000.000000
# mean        0.533995
# std         0.225327
# min         0.030000
# 25%         0.360000
# 50%         0.560000
# 75%         0.710000
# max         1.000000
# Name: job_satisfaction_rate, dtype: float64
# ...
# Количество уникальных значений: 98
# Количество пропусков в датафрейте 0
# ...

# %%
# Графики для датафрейма train
hix_box_plot(train,'job_satisfaction_rate')
# Out:
# /opt/conda/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Общая информация для датафрейма y_test
col_review(y_test, 'job_satisfaction_rate')
# Out:
# Размер: 2000
# ...
# Охарактеризация данных
# count    2000.00000
# mean        0.54878
# std         0.22011
# min         0.03000
# 25%         0.38000
# 50%         0.58000
# 75%         0.72000
# max         1.00000
# Name: job_satisfaction_rate, dtype: float64
# ...
# Количество уникальных значений: 98
# Количество пропусков в датафрейте 0
# ...

# %%
# Графики для датафрейма y_test
hix_box_plot(y_test,'job_satisfaction_rate')
# Out:
# /opt/conda/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Данные столбца выглядят нормально.

# %% [markdown]
# #### Вывод по исследовательскому анализу данных

# %% [markdown]
# * Все данные реалистичны и соответствуют описанию.
# * Имеются пропуски в столбцах:
#   * *`dept`*;
#   * *`level`*;
#   * *`workload`*.
# * Во всех данных заметен дисбаланс.
# * В столбце *`salary`* заметны выбросы, однако выбросы нельзя назвать аномальными.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Верно!👍:\
# </b> Мне интересно было изучить проведенный исследовательский анализ данных, твои графики, осмысленный и красочный графический анализ. Найдены очень интересные закономерности)

# %% [markdown]
# ### Корреляционный анализ данных

# %%
# Строим матрицу корреляций в виде тепловой карты
plt.figure(figsize=(15, 8))
sns.heatmap(train.phik_matrix(interval_cols=['job_satisfaction_rate', 'salary']), annot=True) 
plt.title("Тепловая карта корреляции")
plt.show()
# Out:
# /opt/conda/lib/python3.9/site-packages/phik/data_quality.py:59: UserWarning: The number of unique values of variable id is large: 4000. Are you sure this is not an interval variable? Analysis for pairs of variables including id can be slow.
#   warnings.warn(

# %% [markdown]
# По матрице корреляции можно видеть:
# * *`job_satisfaction_rate`* имеет:
#   * <u>**Высокую связь**</u> с *`supervisor_evaluation`*.
#   * <u>**Заметную связь**</u> с *`last_year_violations`*.
# * *`salary`* имеет:
#   * <u>**Высокую связь**</u> с *`level`* и *`workload`*.
# * *`employment_years`* имеет:
#   * <u>**Заметную связь**</u> с *`level`*.
#
# **Мультиколлинеарность** при пороге в **0,9** между признаками <u>**отсутствует**</u>.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Молодец, что проверяешь попарные корреляции признаков)
#
#
# <br/>
# <div class="alert alert-block alert-danger">
#
#
# <b>На доработку🤔:</b>
#
# Согласно документации `phik_matrix` в `interval_cols` нужно передавать только непрерывные признаки, поэтому в методе phik_matrix нужно указать параметр interval_cols, чтобы phik не определял сам численные признаки.
#
# **На всякий случай обрати внимание, что `employment_years` и `supervisor_evaluation` - дискретные признаки, их нельзя передавать в `interval_cols`.**
#
# Добавлю, что  `job_satisfaction_rate` и `salary` - это непрерывные признаки

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>👋:</b> Добавил, но не до конца понял, как это влияет на корреляции, пока что без изменений получилось. В будущем буду пользоваться, скорее всего пойму. Просто видимо именно на этих данных разница не заметна.
#
# Так же после добавления `interval_cols` он стал считать столбец `id`, функционально не мешает, но визуально портит тепловую карту. Подскажешь, как его исключить из построения матрицы? Или просто перед построением матрицы ставить следующую ячейку с кодом?👇
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Ты абсолютно правильно заметил: столбец `id` действительно лучше исключить, так как он не несёт полезной информации для корреляционного анализа и портит тепловую карту. Переводить его в индекс — вполне рабочее решение, но есть более универсальные подходы, которые не зависят от изменения структуры данных.
#
# Дам несколько вариантов:
#
# ---
#
# **1. Удалить `id` перед вычислением корреляционной матрицы**
# Если `id` нужен для других операций, можно временно удалить его из DataFrame перед расчётом `phik_matrix`:
#
# ```python
# train_without_id = train.drop(columns=['id'])
# phik_corr = train_without_id.phik_matrix(interval_cols=['job_satisfaction_rate', 'salary'])
# ```
#
# ---
#
# **2. Исключить `id` прямо в визуализации**
# Если корреляции уже посчитаны, можно исключить его перед построением тепловой карты:
#
# ```python
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# # Исключаем `id`
# phik_corr_filtered = phik_corr.drop(index='id', columns='id')
#
# # Визуализация
# plt.figure(figsize=(10, 8))
# sns.heatmap(phik_corr_filtered, annot=True, cmap='coolwarm')
# plt.title("Корреляционная матрица (Phik)")
# plt.show()
# ```
#
# ---
#
# **3. Оставить `id` в данных, но игнорировать его в `interval_cols`**
# `id` в таком случае не будет учитываться в расчёте корреляций:
#
# ```python
# interval_cols = ['job_satisfaction_rate', 'salary']  # Только непрерывные признаки
# phik_corr = train.phik_matrix(interval_cols=interval_cols)
# ```
#
# ---
#
# **Почему важно передавать `interval_cols`?**
# Это влияет на интерпретацию корреляции. `Phik` сам пытается определить, какие признаки являются числовыми (непрерывными), но может ошибаться, например, принимая дискретные данные за непрерывные. Указание `interval_cols` гарантирует, что корреляция между непрерывными признаками будет рассчитана корректно, а для категориальных признаков будет использоваться таблица сопряжённости.
#
# На твоих данных разницы может быть незаметно, если все признаки уже корректно определяются автоматически, но это хороший навык для работы с более сложными данными.
#
# ---
#
# Какой вариант лучше?
# Если `id` нужен как индекс для работы, используй первый подход. Если важна гибкость, второй или третий подойдут лучше

# %% [markdown]
# ### Подготовка данных

# %%
# Избавимся от столбца id, преобразив его в индекс датафрейма
train = train.set_index('id')

# %%
# Проверим данные на наличие дубликатов без учёта id
train.duplicated().sum()
# Out:
# 245

# %%
# Избавимся от дубликатов
train = train.drop_duplicates()

# %%
# Проверим итоговую размерность датафрейма
train.shape
# Out:
# (3755, 9)

# %%
# Сохраним выборки
X_train = train.drop(['job_satisfaction_rate'], axis=1)
y_train = train['job_satisfaction_rate']

# %%
# Создадим списки признаков по типу кодировки
ohe_columns = ['dept', 'last_year_promo', 'last_year_violations']

# %%
ord_columns = ['level', 'workload']

# %%
num_columns = ['employment_years', 'supervisor_evaluation', 'salary']

# %% [markdown]
# ### Метрика SMAPE

# %% [markdown]
# **SMAPE** - Cимметричная средняя абсолютная процентная ошибка(Symmetric Mean Absolute Percentage Error). Одной из возможных проблем **SMAPE** является неполная симметрия, поскольку в разных диапазонах ошибка вычисляется неодинаково. Ограничение **SMAPE** заключается в том, что, если наблюдаемое или предсказанное значение равно 0, ошибка резко возрастет до верхнего предела в 200%.

# %%
# Cоздаём функцию для расчёта метрики SMAPE
def smape(y_true, y_pred):
    return 100 / len(y_true) * np.sum(np.abs(y_true - y_pred) / ((np.abs(y_true) + np.abs(y_pred))/2))

# %%
# Cоздаем саму метрику
smape_scorer = make_scorer(smape, greater_is_better=False)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Верно, что задаешь параметр `greater_is_better=False`. Дело в том, что разработчики пакета `sklearn` при создании функций `cross_val_score` и `SearchCV` утвердили соглашение: возвращаемые результаты вычислений данных функций должны соответствовать задаче максимизации (чем большее значение метрики получаем, тем лучше). При этом обратная задача минимизации может быть осуществлена через максимизацию метрики, домноженной на -1. Об этом можно чуть подробнее почитать в документации пакета, правда она на английском. Оставлю <a href = 'https://scikit-learn.org/stable/modules/model_evaluation.html'>ссылку</a>

# %% [markdown]
# ### Подготовка пайплайнов

# %%
# OneHot-кодирование
ohe_pipe = Pipeline(
    [
        ('simpleImputer_ohe', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
        ('ohe', OneHotEncoder(drop='first', handle_unknown='ignore', sparse=False))
    ]
)

# %% [markdown]
#  <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
#
# Здесь есть важный момент, связанный с настройкой бесперебойности этого трансформера: по умолчанию у `OneHotEncoder` параметр `handle_unknown` принимает значение `error`, что приведёт к ошибке в случае, если в `test` или другой не-`train` выборке будут такие значения, которых в `train` не было при обучении трансформера. То есть у `OneHotEncoder` нужно задать у параметра `handle_unknown` значение 'ignore'
#
# Вероятно, потребуется обновление библиотеки sklearn, чтобы избежать ошибки после установки в `handle_unknown` значения 'ignore'.

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>👋:</b> Поправил
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %%
# Ordinal-кодирование
ord_pipe = Pipeline(
    [
        (
            'simple_imputer_ord_before',
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        ),
        (
            'ord',
            OrdinalEncoder(categories=[
                    ['junior', 'middle', 'senior'],
                    ['low', 'medium', 'high']
                ],
                handle_unknown='use_encoded_value',
                          unknown_value=np.nan)
        ),
        (
            'simple_imputer_ord_after',
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        )
    ]
)

# %%
# Подготовка данных
data_preprocessor = ColumnTransformer(
    [('ohe', ohe_pipe, ohe_columns),
     ('ord', ord_pipe, ord_columns),
     ('num', MinMaxScaler(), num_columns)], 
    remainder='passthrough'
)

# %%
# Финальный пайплайн
pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', DecisionTreeRegressor(random_state=RANDOM_STATE))
])

# %% [markdown]
# ### Поиск лучшей модели

# %%
# Задаём словари моделей для подбора лучшей модели
param_grid = [
    # словарь для модели DecisionTreeRegressor()
    {
        'models': [DecisionTreeRegressor(random_state=RANDOM_STATE)],
        'models__max_depth': range(2, 15),
        'models__max_features': range(2, 15),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    # словарь для модели LinearRegression()
    {
        'models': [LinearRegression()],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    }
]

# %%
# Для переборки гиперпараметров используем случайный подбор
randomized_search = RandomizedSearchCV(
    pipe_final, 
    param_grid, 
    cv=5,
    scoring=smape_scorer,
    random_state=RANDOM_STATE,
    n_jobs=-1
)

# %%
# Ищем лучшую модель и гиперпараметры для неё
randomized_search.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('ohe',
#                                                                                Pipeline(steps=[('simpleImputer_ohe',
#                                                                                                 SimpleImputer(strategy='most_frequent')),
#                                                                                                ('ohe',
#                                                                                                 OneHotEncoder(drop='first',
#                                                                                                               handle_unknown='ignore',
# ...

# %%
print('Метрика на тренировочной выборке для лучшей модели:\n', randomized_search.best_score_)
print('\nЛучшая модель и её параметры:\n\n', randomized_search.best_estimator_)
# Out:
# Метрика на тренировочной выборке для лучшей модели:
#  -15.93084234835278
#
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse=False))]),
#                                                   ['dept', 'last_year_promo',
# ...

# %% [markdown]
# Критерий успеха: SMAPE ≤15 на тестовой выборке. Проверим модель на тестовой выборке.

# %%
# Избавимся от id в тестовых выборках
X_test_1 = X_test.set_index('id')
y_test_1 = y_test['job_satisfaction_rate']

# %%
# Найдём предсказания на тестовой выборке и проверим метрику модели
y_pred_1 = randomized_search.best_estimator_.predict(X_test_1)
print(f'Метрика на тестовой выборке: {smape(y_test_1, y_pred_1)}')
# Out:
# Метрика на тестовой выборке: 50.12106067575209

# %% [markdown]
# На тестовых данных метрика показала очень плохой результат. Возможно выборки имеют разный порядок записей. Проверим.

# %%
# Отсортируем обе выборки по id и избавимся от id
X_test_1_new = X_test.sort_values(by='id')
X_test_1_new = X_test_1_new.set_index('id')
y_test_1_new = y_test.sort_values(by='id')
y_test_1_new = y_test_1_new['job_satisfaction_rate']

# %%
# Найдём предсказания на новой тестовой выборке и проверим метрику
y_pred_1_new = randomized_search.best_estimator_.predict(X_test_1_new)
print(f'Метрика на тестовой выборке: {smape(y_test_1_new, y_pred_1_new)}')
# Out:
# Метрика на тестовой выборке: 14.22813561799784

# %% [markdown]
# Предположение оказалось верно. Значение метрики(**14.23**) подходит под критерий успеха. Успешная модель найдена. Задачу можно считать выполненой.

# %% [markdown]
# ### Результаты подбора моделей

# %%
# Сохраним результаты подбора лучшей модели в датафрейм
results = pd.DataFrame(randomized_search.cv_results_)

# %%
# Выведем результаты на экран
results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.025856      0.004751         0.008883        0.000153
# 1       0.020842      0.000132         0.007995        0.000390
# 2       0.024185      0.004243         0.009887        0.001544
# 3       0.020719      0.003702         0.007701        0.000570
# 4       0.019683      0.000568         0.007804        0.000538
# 5       0.031015      0.021105         0.019330        0.021033
# 6       0.041338      0.025193         0.019209        0.020523
# 7       0.032683      0.018358         0.030689        0.026962
# 8       0.057645      0.025115         0.019921        0.020857
# 9       0.044055      0.026072         0.008034        0.000476
#
#   param_preprocessor__num param_models__max_features param_models__max_depth  \
# 0        StandardScaler()                          6                      14
# 1             passthrough                          8                      13
# ...

# %% [markdown]
# ### Вывод по лучшей модели

# %% [markdown]
# Лучшая модель получилась **DecisionTreeRegressor** с гиперпараметрами **max_depth=13** и **max_features=8**. Метрика **SMAPE** показала значения:
# * **-15.93** на тренировочной выборке;
# * **14.23** на тестовой выборке. ✅

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Тестирование модели проведено. Отлично, что в кросс-валидаторе выше был указан параметр scoring cо sMAPE скорером

# %% [markdown]
# ### Общий вывод по первой задаче

# %% [markdown]
# В данном проекте была проделана следующая работа:
# 1. Загрузка данных - все данные успешно загружены;
# 2. Предобработка данных:
#   * Дубликаты не обнаружены;
#   * Типы данных верные;
#   * Названия столбцов имею "змеиный регистр";
#   * Обнаружены пропуски.
# 3. Иследовательский анализ данных:
#   * Все данные реалистичны и соответствуют описанию.
#   * Имеются пропуски в столбцах:
#     * *`dept`*;
#     * *`level`*;
#     * *`workload`*.
#   * Во всех данных заметен дисбаланс.
#   * В столбце *`salary`* заметны выбросы, однако выбросы нельзя назвать аномальными.
# 4. Корреляционный анализ:
#   * *`job_satisfaction_rate`* имеет:
#     * <u>***Высокую связь***</u> с *`supervisor_evaluation`*.
#     * <u>***Заметную связь***</u> с *`last_year_violations`*.
#   * *`salary`* имеет:
#     * <u>***Высокую связь***</u> с *`level`* и *`workload`*.
#   * *`employment_years`* имеет:
#     * <u>***Заметную связь***</u> с *`level`*.
#   * **Мультиколлинеарность** при пороге в **0,9** между признаками <u>**отсутствует**</u>.
# 5. Данные успешно подготовлены к построению модели.
# 6. Метрика SMAPE успешно создана.
# 7. Пайплайны успешно подготовлены.
# 8. Лучшая модель успешно найдена:
#   * Лучшая модель **DecisionTreeRegressor** имеет следующие гиперпараметры:
#     * **max_depth=13**.
#     * **max_features=8**.
#   * Во время тестирования модели метрика **SMAPE** показала результат в **50.12**, после переподготовки тестовых выборок метрика **SMAPE** показала результат в **14.23**.
#   * С учётом критерия успеха, заданного  в построении задачи, <u>**построение модели можно считать успешным**</u>.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера  <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Приятно видеть общий вывод)

# %% [markdown]
# ## Модель предсказания увольнения сотрудника

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# В этой задаче по аналогичным заданиям и действиям в проекте -  аналогичные замечания (я их привел выше в первой части проекта), без исправления которых проект принят не будет.
#
# Новые неповторяющиеся замечания будут даны ниже отдельно

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>👋:</b> Поправил
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %% [markdown]
# ### Загрузка данных

# %%
# Загружаем данные с возможностью загрузить их с сервера в случае недоступности локальных файлов
try:
    train_2 = pd.read_csv('/datasets/train_quit.csv')
    X_test_2 = pd.read_csv('/datasets/test_features.csv')
    y_test_2 = pd.read_csv('/datasets/test_target_quit.csv')
except:
    train_2 = pd.read_csv('https://code.s3.yandex.net/datasets/train_quit.csv')
    X_test_2 = pd.read_csv('https://code.s3.yandex.net/datasets/test_features.csv')
    y_test_2 = pd.read_csv('https://code.s3.yandex.net/datasets/test_target_quit.csv')

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# #### train_2

# %%
# Обзор датафрейма train
df_review(train_2, 'train_2')
# Out:
# Краткое содержание датафрейма train_2
#        id        dept   level workload  employment_years last_year_promo  \
# 0  723290       sales  middle     high                 2              no
# 1  814010       sales  junior   medium                 2              no
# 2  155091  purchasing  middle   medium                 5              no
# 3  257132       sales  junior   medium                 2              no
# 4  910140   marketing  junior   medium                 2              no
#
#   last_year_violations  supervisor_evaluation  salary quit
# 0                   no                      4   54000   no
# 1                   no                      4   27600   no
# 2                   no                      1   37200   no
# 3                  yes                      3   24000  yes
# 4                   no                      5   25200   no
# ...
# Информация о датафрейме train_2
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# ...

# %%
# Проверим некоторые столбцы датафрейма на наличие неявных дубликатов
train_2['dept'].sort_values().unique()
# Out:
# array(['hr', 'marketing', 'purchasing', 'sales', 'technology'],
#       dtype=object)

# %%
train_2['level'].sort_values().unique()
# Out:
# array(['junior', 'middle', 'sinior'], dtype=object)

# %%
train_2['workload'].sort_values().unique()
# Out:
# array(['high', 'low', 'medium'], dtype=object)

# %% [markdown]
# **Вывод** по *`train_2`*:
# * Дубликаты не обнаружены;
# * Типы данных верные;
# * Названия столбцов имею "змеиный регистр";
# * Пропуски не обнаружены.

# %% [markdown]
# #### X_test_2

# %%
# Обзор датафрейма X_test_2
df_review(X_test_2, 'X_test_2')
# Out:
# Краткое содержание датафрейма X_test_2
#        id       dept   level workload  employment_years last_year_promo  \
# 0  485046  marketing  junior   medium                 2              no
# 1  686555         hr  junior   medium                 1              no
# 2  467458      sales  middle      low                 5              no
# 3  418655      sales  middle      low                 6              no
# 4  789145         hr  middle   medium                 5              no
#
#   last_year_violations  supervisor_evaluation  salary
# 0                   no                      5   28800
# 1                   no                      4   30000
# 2                   no                      4   19200
# 3                   no                      4   19200
# 4                   no                      5   40800
# ...
# Информация о датафрейме X_test_2
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
# ...

# %%
# Проверим некоторые столбцы датафрейма на наличие неявных дубликатов
X_test_2['dept'].sort_values().unique()
# Out:
# array([' ', 'hr', 'marketing', 'purchasing', 'sales', 'technology', nan],
#       dtype=object)

# %%
X_test_2['level'].sort_values().unique()
# Out:
# array(['junior', 'middle', 'sinior', nan], dtype=object)

# %%
X_test_2['workload'].sort_values().unique()
# Out:
# array([' ', 'high', 'low', 'medium'], dtype=object)

# %% [markdown]
# Неявные дубликаты не найдены, однако можно заметить значения в виде пробелов. Заменим их на nan для дальнейшей обработки во время подготовки данных к построения модели.

# %%
X_test_2['dept'] = X_test_2['dept'].replace(' ', np.nan)
X_test_2['workload'] = X_test_2['workload'].replace(' ', np.nan)

# %%
# Ещё раз проверим уникальные значения столбцов
X_test_2['dept'].sort_values().unique()
# Out:
# array(['hr', 'marketing', 'purchasing', 'sales', 'technology', nan],
#       dtype=object)

# %%
X_test_2['workload'].sort_values().unique()
# Out:
# array(['high', 'low', 'medium', nan], dtype=object)

# %% [markdown]
# **Вывод** по *`X_test_2`*:
# * Дубликаты не обнаружены;
# * Типы данных верные;
# * Названия столбцов имею "змеиный регистр";
# * Обнаружены пропуски, заполним их во время подготовки данных к построению модели.

# %% [markdown]
# #### y_test_2

# %%
# Обзор датафрейма y_test_2
df_review(y_test_2, 'y_test_2')
# Out:
# Краткое содержание датафрейма y_test_2
#        id quit
# 0  999029  yes
# 1  372846   no
# 2  726767   no
# 3  490105   no
# 4  416898  yes
# ...
# Информация о датафрейме y_test_2
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2000 non-null   int64
#  1   quit    2000 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 31.4+ KB
# ...
# Размер датафрейма y_test_2 : (2000, 2)
# ...
# Охарактеризация числовых данных датафрейма y_test_2
#      count unique top  freq
# quit  2000      2  no  1436
# ...
# Количество явных дубликатов в датафрейте y_test_2 : 0
# Количество пропусков в датафрейте y_test_2 :
#  id      0
# quit    0
# dtype: int64

# %% [markdown]
# **Вывод** по *`y_test_2`*:
# * Дубликаты не обнаружены;
# * Типы данных верные;
# * Названия столбцов имею "змеиный регистр";
# * Пропуски не обнаружены.

# %% [markdown]
# #### Вывод по предобработке данных

# %% [markdown]
# * Дубликаты не обнаружены;
# * Типы данных верные;
# * Названия столбцов имею "змеиный регистр";
# * Обнаружены пропуски, заполним их во время подготовки данных к построению модели.

# %% [markdown]
# ### Исследовательский анализ данных

# %% [markdown]
# Исследовательский анализ данных будем проводить по каждому столбцу. Т.к. исследователский анализ тестовой выборки мы проводили в работе с первой задачей и выборка осталась та же, то анализировать будем только тренировочную выборку и выборку с тестовым целевым признаком.

# %% [markdown]
# #### id — уникальный идентификатор сотрудника

# %%
# Количество уникальных значений для датафрейма train
train_2['id'].unique().shape[0]
# Out:
# 4000

# %% [markdown]
# Все значения id сотрудников уникальны.

# %% [markdown]
# #### dept — отдел, в котором работает сотрудник

# %%
# Общая информация для датафрейма train_2
col_review(train_2, 'dept')
# Out:
# Размер: 4000
# ...
# Охарактеризация данных
# count      4000
# unique        5
# top       sales
# freq       1438
# Name: dept, dtype: object
# ...
# Количество уникальных значений: 5
# Количество пропусков в датафрейте 0
# ...
# Уникальные значения:
# sales         1438
# technology     928
# purchasing     588
# marketing      582
# hr             464
# Name: dept, dtype: int64

# %%
# Графики для датафрейма train_2
bar_pie_plot(train_2, 'dept')

# %% [markdown]
# Данный столбец имеет 5 уникальных значений, одинаковых в тренировочном и тестовом датафреймах. Заметен дисбаланс значений.

# %% [markdown]
# #### level — уровень занимаемой должности

# %%
# Общая информация для датафрейма train_2
col_review(train_2, 'level')
# Out:
# Размер: 4000
# ...
# Охарактеризация данных
# count       4000
# unique         3
# top       junior
# freq        1949
# Name: level, dtype: object
# ...
# Количество уникальных значений: 3
# Количество пропусков в датафрейте 0
# ...
# Уникальные значения:
# junior    1949
# middle    1694
# sinior     357
# Name: level, dtype: int64

# %%
# Графики для датафрейма train_2
bar_pie_plot(train_2, 'level')

# %% [markdown]
# Данный столбец имеет 3 уникальных значения, одинаковых в тренировочном и тестовом датафреймах. Заметен дисбаланс значений.

# %% [markdown]
# #### workload — уровень загруженности сотрудника

# %%
# Общая информация для датафрейма train_2
col_review(train_2, 'workload')
# Out:
# Размер: 4000
# ...
# Охарактеризация данных
# count       4000
# unique         3
# top       medium
# freq        2118
# Name: workload, dtype: object
# ...
# Количество уникальных значений: 3
# Количество пропусков в датафрейте 0
# ...
# Уникальные значения:
# medium    2118
# low       1208
# high       674
# Name: workload, dtype: int64

# %%
# Графики для датафрейма train_2
bar_pie_plot(train_2, 'workload')

# %% [markdown]
# Данный столбец имеет 3 уникальных значения, одинаковых в тренировочном и тестовом датафреймах. Заметен дисбаланс значений.

# %% [markdown]
# #### employment_years — длительность работы в компании (в годах)

# %%
# Общая информация для датафрейма train_2
col_review(train_2, 'employment_years')
# Out:
# Размер: 4000
# ...
# Охарактеризация данных
# count    4000.000000
# mean        3.701500
# std         2.541852
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         6.000000
# max        10.000000
# Name: employment_years, dtype: float64
# ...
# Количество уникальных значений: 10
# Количество пропусков в датафрейте 0
# ...

# %%
# Графики для датафрейма train_2
bar_pie_plot(train_2,'employment_years')

# %% [markdown]
# В значениях данного столбца заметен дисбаланс значений. В компании явно работает достаточно много новых сотрудников.

# %% [markdown]
# #### last_year_promo — показывает, было ли повышение за последний год

# %%
# Общая информация для датафрейма train_2
col_review(train_2, 'last_year_promo')
# Out:
# Размер: 4000
# ...
# Охарактеризация данных
# count     4000
# unique       2
# top         no
# freq      3887
# Name: last_year_promo, dtype: object
# ...
# Количество уникальных значений: 2
# Количество пропусков в датафрейте 0
# ...
# Уникальные значения:
# no     3887
# yes     113
# Name: last_year_promo, dtype: int64

# %%
# Графики для датафрейма train_2
bar_pie_plot(train_2, 'last_year_promo')

# %% [markdown]
# В значениях данного столбца заметен дисбаланс значений. В компании всего около 3% сотрудников получили повышение за последний год.

# %% [markdown]
# #### last_year_violations — показывает, нарушал ли сотрудник трудовой договор за последний год

# %%
# Общая информация для датафрейма train_2
col_review(train_2, 'last_year_violations')
# Out:
# Размер: 4000
# ...
# Охарактеризация данных
# count     4000
# unique       2
# top         no
# freq      3455
# Name: last_year_violations, dtype: object
# ...
# Количество уникальных значений: 2
# Количество пропусков в датафрейте 0
# ...
# Уникальные значения:
# no     3455
# yes     545
# Name: last_year_violations, dtype: int64

# %%
# Графики для датафрейма train_2
bar_pie_plot(train_2, 'last_year_violations')

# %% [markdown]
# В значениях данного столбца заметен дисбаланс значений. В компании около 14% сотрудников нарушали трудовой договор за последний год.

# %% [markdown]
# #### supervisor_evaluation — оценка качества работы сотрудника, которую дал руководитель

# %%
# Общая информация для датафрейма train_2
col_review(train_2, 'supervisor_evaluation')
# Out:
# Размер: 4000
# ...
# Охарактеризация данных
# count    4000.000000
# mean        3.474750
# std         1.004049
# min         1.000000
# 25%         3.000000
# 50%         4.000000
# 75%         4.000000
# max         5.000000
# Name: supervisor_evaluation, dtype: float64
# ...
# Количество уникальных значений: 5
# Количество пропусков в датафрейте 0
# ...

# %%
# Графики для датафрейма train_2
bar_pie_plot(train_2, 'supervisor_evaluation')

# %% [markdown]
# В значениях данного столбца заметен дисбаланс значений. В компании около 72% сотрудников имеют хорошую оценку руководителя.

# %% [markdown]
# #### salary — ежемесячная зарплата сотрудника

# %%
# Общая информация для датафрейма train_2
col_review(train_2, 'salary')
# Out:
# Размер: 4000
# ...
# Охарактеризация данных
# count     4000.000000
# mean     33805.800000
# std      15152.415163
# min      12000.000000
# 25%      22800.000000
# 50%      30000.000000
# 75%      43200.000000
# max      96000.000000
# Name: salary, dtype: float64
# ...
# Количество уникальных значений: 69
# Количество пропусков в датафрейте 0
# ...

# %%
# Графики для датафрейма train_2
hix_box_plot(train_2,'salary')
# Out:
# /opt/conda/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# В значениях данного столбца заметны выбросы. Выбросы не аномальны, т.к. такие зарплаты вполне реальны для высококвалифицированных сотрудников.

# %% [markdown]
# #### quit - увольнение сотрудника из компании, целевой признак второй задачи

# %%
# Общая информация для датафрейма train_2
col_review(train_2, 'quit')
# Out:
# Размер: 4000
# ...
# Охарактеризация данных
# count     4000
# unique       2
# top         no
# freq      2872
# Name: quit, dtype: object
# ...
# Количество уникальных значений: 2
# Количество пропусков в датафрейте 0
# ...
# Уникальные значения:
# no     2872
# yes    1128
# Name: quit, dtype: int64

# %%
# Графики для датафрейма train_2
bar_pie_plot(train_2,'quit')

# %%
# Общая информация для датафрейма y_test_2
col_review(y_test_2, 'quit')
# Out:
# Размер: 2000
# ...
# Охарактеризация данных
# count     2000
# unique       2
# top         no
# freq      1436
# Name: quit, dtype: object
# ...
# Количество уникальных значений: 2
# Количество пропусков в датафрейте 0
# ...
# Уникальные значения:
# no     1436
# yes     564
# Name: quit, dtype: int64

# %%
# Графики для датафрейма y_test_2
bar_pie_plot(y_test_2,'quit')

# %% [markdown]
# Данные столбца выглядят нормально.

# %% [markdown]
# #### Вывод по исследовательскому анализу данных

# %% [markdown]
# * Все данные реалистичны и соответствуют описанию.
# * Во всех данных заметен дисбаланс.
# * В столбце *`salary`* заметны выбросы, однако выбросы нельзя назвать аномальными.

# %% [markdown]
# ### Портрет "уволившегося сотрудника"

# %% [markdown]
# Для начала распределим зарплаты сотрудников по категориям.

# %%
# Скопируем датафрейм
train_2_new = train_2.copy(deep=True)

# %%
# Добавляем новый столбец с категориями зарплат заранее подготовленной функцией
train_2_new['salary_cat'] = train_2['salary'].apply(salary_cat)

# %%
# Проверим датафрейм
train_2_new.head()
# Out:
#        id        dept   level workload  employment_years last_year_promo  \
# 0  723290       sales  middle     high                 2              no
# 1  814010       sales  junior   medium                 2              no
# 2  155091  purchasing  middle   medium                 5              no
# 3  257132       sales  junior   medium                 2              no
# 4  910140   marketing  junior   medium                 2              no
#
#   last_year_violations  supervisor_evaluation  salary quit salary_cat
# 0                   no                      4   54000   no     40-60к
# 1                   no                      4   27600   no     20-40к
# 2                   no                      1   37200   no     20-40к
# 3                  yes                      3   24000  yes     20-40к
# 4                   no                      5   25200   no     20-40к

# %%
# Создадим список признаков для анализа
tag_to_analyse = train_2_new.select_dtypes(exclude='number').columns.tolist()
tag_to_analyse.extend(['supervisor_evaluation','employment_years'])
tag_to_analyse.remove('quit')

# %%
# Проверим список признаков
tag_to_analyse
# Out:
# ['dept',
#  'level',
#  'workload',
#  'last_year_promo',
#  'last_year_violations',
#  'salary_cat',
#  'supervisor_evaluation',
#  'employment_years']

# %%
#Построим субплот графиков соотношения уволившихся сотрудников к работающим по каждому из признаков
fig, ax = plt.subplots(nrows=4, ncols=1, figsize=(15,20))
fig.suptitle(f'Гистограммы анализа', fontsize = 25, fontweight='bold')

temp = 1
for i in tag_to_analyse:
    plt.subplot(4, 2, temp)
    sns.countplot(x = i, data = train_2_new, hue = 'quit')
    temp += 1
    plt.title(f'{i}', fontsize = 15, fontweight='bold')
    plt.ylabel('кол-во сотрудников', fontsize = 15)

plt.tight_layout()

# %%
# Выведем процентное соотношение уволившихся сотрудников по каждому признаку
for i in tag_to_analyse:
    for j in train_2_new[i].unique():        
        print('Процент уволившихся сотрудников', i, j, round(train_2_new[(train_2_new[i] == j) & (train_2_new['quit'] == 'yes')]\
                         .shape[0]/(train_2_new[(train_2_new[i] == j)].shape[0])*100,2), '%')
    print('='*100)
# Out:
# Процент уволившихся сотрудников dept sales 28.3 %
# Процент уволившихся сотрудников dept purchasing 28.23 %
# Процент уволившихся сотрудников dept marketing 28.01 %
# Процент уволившихся сотрудников dept technology 29.74 %
# Процент уволившихся сотрудников dept hr 25.0 %
# ...
# Процент уволившихся сотрудников level middle 6.38 %
# Процент уволившихся сотрудников level junior 51.46 %
# Процент уволившихся сотрудников level sinior 4.76 %
# ...
# Процент уволившихся сотрудников workload high 17.95 %
# Процент уволившихся сотрудников workload medium 23.04 %
# Процент уволившихся сотрудников workload low 42.96 %
# ...
# Процент уволившихся сотрудников last_year_promo no 28.99 %
# Процент уволившихся сотрудников last_year_promo yes 0.88 %
# ...
# Процент уволившихся сотрудников last_year_violations no 26.05 %
# Процент уволившихся сотрудников last_year_violations yes 41.83 %
# ...
# Процент уволившихся сотрудников salary_cat 40-60к 6.76 %
# Процент уволившихся сотрудников salary_cat 20-40к 29.52 %
# ...

# %% [markdown]
# **Выводы по портрету "уволившегося сотрудника":**
# * Больше всего уволившихся сотрудников работало в отделе **sales**, однако в процентном соотношениичаще всего сотрудники из отдела **technology**;
# * Абсолютное большинство сотрудников уволилось с уровнем **junior** как в количественном, так и в процентном соотношении;
# * Большинство сотрудников уволилось при уровне загруженности **low** как в количественном, так и в процентном соотношении;
# * Большинство сотрудников уволилось **не получив повышение за год**;
# * Большинство уволившихся сотрудников **не имело нарушений трудового договора**, однако в процентном соотношении сотрудники, **имеющие нарушения по трудовому договору, увольняются чаще**;
# * Большинство уволившихся сотрудников имели зарплату **от 20 до 40тыс.**, однако сотрудники с зарплатой **менее 20тыс.** чаще увольняются, чем нет;
# * Большинство уволившихся сотрудников имели оценку работодателя **3**, однако сотрудники с оценкой руководителя **1** чаще увольняются;
# * Большинство сотрудников уволилось **проработав всего год** как в количественном, так и в процентном соотношении;

# %% [markdown]
# **Портрет "уволившегося сотрудника"**: сотрудник работал в отделе *technology*, имея уровень квалификации *junior*, зарплату менее 20тыс., не имея большой загруженности и не получив повышение за год. За сотрудником были замечены нарушения по трудовому договору. Оценка работы данного сотрудника, выставленная руководителем, равна 1 баллу. СТаж работы сотрудника на данной предприятии всего 1 год.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Молодец, что используешь относительные значения в описании портрета уволившегося сотрудника

# %% [markdown]
# ### Распределения признака job_satisfaction_rate для ушедших и оставшихся сотрудников

# %%
# Сформируем общий датафрейм из тестовых выборок
test = X_test_2.merge(y_test, on='id')
test = test.merge(y_test_2, on='id')

# %%
# Проверим датафрейм
test.head()
# Out:
#        id       dept   level workload  employment_years last_year_promo  \
# 0  485046  marketing  junior   medium                 2              no
# 1  686555         hr  junior   medium                 1              no
# 2  467458      sales  middle      low                 5              no
# 3  418655      sales  middle      low                 6              no
# 4  789145         hr  middle   medium                 5              no
#
#   last_year_violations  supervisor_evaluation  salary  job_satisfaction_rate  \
# 0                   no                      5   28800                   0.79
# 1                   no                      4   30000                   0.72
# 2                   no                      4   19200                   0.64
# 3                   no                      4   19200                   0.60
# 4                   no                      5   40800                   0.75
#
#   quit
# 0   no
# 1   no
# 2   no
# 3   no
# 4   no

# %% [markdown]
# **Задача**: Аналитики утверждают, что уровень удовлетворённости сотрудника работой в компании влияет на то, уволится ли сотрудник.
#
# Определяем нулевую(H0) и альтернативную(H1) гипотезы:
# * **H0:** Средняя удовлетворённость сотрудника у уволившихся и оставшихся равно;
# * **H1:** Средняя удовлетворённость сотрудника у уволившихся меньше, чем у оставшихся.

# %%
# Примем уровень статистической значимости равно .05
alpha = 0.05

# Посчитаем p-значение
# Для правосторонней альтернативной гипотезы используем параметр 'greater'
results = st.ttest_ind(test[test['quit'] == 'no']['job_satisfaction_rate'],
                       test[test['quit'] == 'yes']['job_satisfaction_rate'], 
                       alternative='greater')
print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение: 6.155610332585965e-105
# Отвергаем нулевую гипотезу

# %%
#Сравним среднюю удовлетворённость сотрудника 
print('Средняя удовлетворённость уволившегося сотрудника:', test[test['quit'] == 'yes']\
      ['job_satisfaction_rate'].mean().round(2))
print('Средняя удовлетворённость работающего сотрудника:', test[test['quit'] == 'no']\
      ['job_satisfaction_rate'].mean().round(2))
# Out:
# Средняя удовлетворённость уволившегося сотрудника: 0.39
# Средняя удовлетворённость работающего сотрудника: 0.61

# %% [markdown]
# **Вывод**: Нулевую гипотезу можно отвергнуть, значит утверждение аналитиков может быть верно.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Молодец, что сравниваешь выборки с проведением статтеста

# %% [markdown]
# ### Корреляционный анализ данных

# %%
# Строим матрицу корреляций в виде тепловой карты
plt.figure(figsize=(15, 8))
sns.heatmap(train_2.phik_matrix(interval_cols=['salary']), annot=True) 
plt.title("Тепловая карта корреляции")
plt.show()
# Out:
# /opt/conda/lib/python3.9/site-packages/phik/data_quality.py:59: UserWarning: The number of unique values of variable id is large: 4000. Are you sure this is not an interval variable? Analysis for pairs of variables including id can be slow.
#   warnings.warn(

# %% [markdown]
# По матрице корреляции можно видеть:
# * *`quit`* имеет:
#   * <u>**Заметную связь**</u> с *`employment_years`* и *`salary`*.
# * *`salary`* имеет:
#   * <u>**Высокую связь**</u> с *`level`* и *`workload`*.
# * *`employment_years`* имеет:
#   * <u>**Заметную связь**</u> с *`level`*.
#
# **Мультиколлинеарность** при пороге в **0,9** между признаками <u>**отсутствует**</u>.

# %% [markdown]
# ### Добавление нового входного признака

# %% [markdown]
# Допустим, *`job_satisfaction_rate`* и *`quit`* действительно связаны имы получили необходимое значение метрики в первой задаче. Добавим *`job_satisfaction_rate`*, предсказанный лучшей моделью первой задачи, к входным признакам второй задачи.

# %%
# Добавим признак job_satisfaction_rate, предсказанный лучшей моделью первой задачи, к входным признакам второй задачи.
train_2['job_satisfaction_rate_pred'] = randomized_search.best_estimator_.predict(train_2.drop(['quit'], axis=1))

# %%
# Проверим датафрейм
train_2.head()
# Out:
#        id        dept   level workload  employment_years last_year_promo  \
# 0  723290       sales  middle     high                 2              no
# 1  814010       sales  junior   medium                 2              no
# 2  155091  purchasing  middle   medium                 5              no
# 3  257132       sales  junior   medium                 2              no
# 4  910140   marketing  junior   medium                 2              no
#
#   last_year_violations  supervisor_evaluation  salary quit  \
# 0                   no                      4   54000   no
# 1                   no                      4   27600   no
# 2                   no                      1   37200   no
# 3                  yes                      3   24000  yes
# 4                   no                      5   25200   no
#
#    job_satisfaction_rate_pred
# 0                    0.648000
# 1                    0.834583
# 2                    0.363810
# 3                    0.337500
# ...

# %%
# Добавим этот же признак для тестовой выборки
X_test_2['job_satisfaction_rate_pred'] = randomized_search.best_estimator_.predict(X_test_2)

# %%
# Проверим датафрейм
X_test_2.head()
# Out:
#        id       dept   level workload  employment_years last_year_promo  \
# 0  485046  marketing  junior   medium                 2              no
# 1  686555         hr  junior   medium                 1              no
# 2  467458      sales  middle      low                 5              no
# 3  418655      sales  middle      low                 6              no
# 4  789145         hr  middle   medium                 5              no
#
#   last_year_violations  supervisor_evaluation  salary  \
# 0                   no                      5   28800
# 1                   no                      4   30000
# 2                   no                      4   19200
# 3                   no                      4   19200
# 4                   no                      5   40800
#
#    job_satisfaction_rate_pred
# 0                    0.842308
# 1                    0.682222
# 2                    0.643333
# 3                    0.671538
# 4                    0.816667

# %% [markdown]
# **Вывод:** Новый признак успешно добавлен к тренировочной и тестовой выборкам.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Хорошо, признак job_satisfaction_rate добавлен в тренировочную и тестовую выборки, а значения предсказаны с помощью лучшей модели регрессии, обученной в прошлой части задачи

# %% [markdown]
# ### Подготовка данных

# %%
# Избавимся от столбца id, преобразив его в индекс датафрейма
train_2 = train_2.set_index('id')

# %%
# Проверим данные на наличие дубликатов без учёта id
train_2.duplicated().sum()
# Out:
# 1413

# %%
# Избавимся от дубликатов
train_2 = train_2.drop_duplicates()

# %%
# Проверим итоговую размерность датафрейма
train_2.shape
# Out:
# (2587, 10)

# %%
# Сохраним выборки
X_train_2 = train_2.drop(['quit'], axis=1)
y_train_2 = train_2['quit']

# %%
# Отсортируем обе тестовые выборки по id и избавимся от id
X_test_2 = X_test_2.sort_values(by='id')
X_test_2 = X_test_2.set_index('id')
y_test_2 = y_test_2.sort_values(by='id')
y_test_2 = y_test_2['quit']

# %%
# Создадим списки признаков по типу кодировки
ohe_columns_2 = ['dept', 'last_year_promo', 'last_year_violations']

# %%
ord_columns_2 = ['level', 'workload']

# %%
num_columns_2 = ['salary', 'job_satisfaction_rate_pred']

# %% [markdown]
# ### Подготовка пайплайнов

# %%
# Подготовка данных
data_preprocessor_2 = ColumnTransformer(
    [('ohe', ohe_pipe, ohe_columns_2),
     ('ord', ord_pipe, ord_columns_2),
     ('num', MinMaxScaler(), num_columns_2)], 
    remainder='passthrough'
)

# %%
# Финальный пайплайн
pipe_final_2 = Pipeline([
    ('preprocessor', data_preprocessor_2),
    ('models', DecisionTreeClassifier(random_state=RANDOM_STATE))
])

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Для кодирования таргета стоит использовать label encoder. Заранее предупрежу, что обучать `LabelEncoder()` нужно будет на тренировочной выборке, а потом метод `transform` уже применять к тестовой выборке: https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html.
#
#
#     le = LabelEncoder()
#     le.fit_transform(X_train['quit'])
#     le.transform(X_test['quit'])

# %% [markdown]
# ### Поиск лучшей модели

# %%
# Задаём словари моделей для подбора лучшей модели
param_grid_2 = [
    # словарь для модели DecisionTreeClassifier()
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': range(2,30),
        'models__max_features': range(2,30),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    
    # словарь для модели KNeighborsClassifier() 
    {
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': range(2,20),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']   
    },

    # словарь для модели LogisticRegression()
    {
        'models': [LogisticRegression(
            random_state=RANDOM_STATE, 
            solver='liblinear', 
            penalty='l1'
        )],
        'models__C': range(1,20),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    
    # словарь для модели CVС()
    {
        'models': [SVC(
            random_state=RANDOM_STATE,
            probability=True
        )],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough'],
        'models__kernel': ['linear', 'rbf']
    }
    
       
]

# %%
# Для переборки гиперпараметров используем случайный подбор
randomized_search_2 = RandomizedSearchCV(
    pipe_final_2, 
    param_grid_2, 
    cv=10,
    scoring='roc_auc',
    random_state=RANDOM_STATE,
    n_jobs=-1
)

# %%
# Ищем лучшую модель и гиперпараметры для неё
randomized_search_2.fit(X_train_2, y_train_2)
# Out:
# RandomizedSearchCV(cv=10,
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('ohe',
#                                                                                Pipeline(steps=[('simpleImputer_ohe',
#                                                                                                 SimpleImputer(strategy='most_frequent')),
#                                                                                                ('ohe',
#                                                                                                 OneHotEncoder(drop='first',
#                                                                                                               handle_unknown='ignore',
# ...

# %%
print('Метрика на тренировочной выборке для лучшей модели:\n', randomized_search_2.best_score_)
print('\nЛучшая модель и её параметры:\n\n', randomized_search_2.best_estimator_)
# Out:
# Метрика на тренировочной выборке для лучшей модели:
#  0.89580131707048
#
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse=False))]),
#                                                   ['dept', 'last_year_promo',
# ...

# %% [markdown]
# Критерий успеха:  ROC-AUC ≥0.91 на тестовой выборке.. Проверим модель на тестовой выборке.

# %%
# Найдём предсказания на тестовой выборке и проверим метрику модели
y_pred_2 = randomized_search_2.best_estimator_.predict_proba(X_test_2)[:,1]
print(f'Метрика на тестовой выборке: {roc_auc_score(y_test_2, y_pred_2)}')
# Out:
# Метрика на тестовой выборке: 0.9177161737687429

# %% [markdown]
# ### Результаты подбора моделей

# %%
# Сохраним результаты подбора лучшей модели в датафрейм
results_2 = pd.DataFrame(randomized_search_2.cv_results_)

# %%
# Выведем результаты на экран
results_2
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.020145      0.000694         0.007970        0.000300
# 1       0.025278      0.002142         0.010143        0.001581
# 2       0.023593      0.001423         0.009505        0.001516
# 3       0.028375      0.003042         0.011794        0.001943
# 4       0.028453      0.004367         0.010914        0.001811
# 5       0.025044      0.000418         0.009968        0.000718
# 6       0.023242      0.000806         0.010201        0.001057
# 7       0.022237      0.000584         0.008531        0.000358
# 8       0.025618      0.003773         0.010817        0.001850
# 9       0.025898      0.001345         0.010055        0.000425
#
#   param_preprocessor__num param_models__max_features param_models__max_depth  \
# 0             passthrough                          8                      12
# 1          MinMaxScaler()                         13                      17
# ...

# %% [markdown]
# ### Вывод по лучшей модели

# %% [markdown]
# Лучшая модель получилась **DecisionTreeClassifier** с гиперпараметрами **max_depth=5** и **max_features=28**. Метрика **ROC-AUC** показала значения:
# * **0.9** на тренировочной выборке;
# * **0.92** на тестовой выборке. ✅

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# На тестовой выборке получено хорошее качество) Отлично, что в кросс-валидаторе выше в параметре scoring был задан 'roc_auc'

# %% [markdown]
# ### Общий вывод по второй задаче

# %% [markdown]
# В данном проекте была проделана следующая работа:
# 1. Загрузка данных - все данные успешно загружены;
# 2. Предобработка данных:
#   * Дубликаты не обнаружены;
#   * Типы данных верные;
#   * Названия столбцов имею "змеиный регистр";
#   * Обнаружены пропуски.
# 3. Иследовательский анализ данных:
#   * Все данные реалистичны и соответствуют описанию.
#   * Во всех данных заметен дисбаланс.
#   * В столбце *`salary`* заметны выбросы, однако выбросы нельзя назвать аномальными.
# 4. Портрет "уволившегося сотрудника" успешно построен.
# 5. Утверждение аналитиков о том, что уровень удовлетворённости сотрудника работой в компании влияет на то, уволится ли сотрудник, успешно проверено. Утверждение можно считать верным.
# 6. Корреляционный анализ:
#   * *`quit`* имеет:
#     * <u>**Заметную связь**</u> с *`employment_years`* и *`salary`*.
#   * *`salary`* имеет:
#     * <u>**Высокую связь**</u> с *`level`* и *`workload`*.
#   * *`employment_years`* имеет:
#     * <u>**Заметную связь**</u> с *`level`*.
#   * **Мультиколлинеарность** при пороге в **0,9** между признаками <u>**отсутствует**</u>.
# 7. Новый входной признак успешно добавлен.
# 8. Данные успешно подготовлены к построению модели.
# 9. Пайплайны успешно подготовлены.
# 10. Лучшая модель успешно найдена:
#   * Лучшая модель **DecisionTreeClassifier** имеет следующие гиперпараметры:
#     * **max_depth=5**.
#     * **max_features=28**.
#   * Во время тестирования модели метрика **ROC-AUC** показала результат в **0.9** на тренировочной выборке и **0,92** на тестовой выборке.
#   * С учётом критерия успеха, заданного  в построении задачи, <u>**построение модели можно считать успешным**</u>.
#
#
# **Портрет "уволившегося сотрудника"**: сотрудник работал в отделе technology, имея уровень квалификации junior, зарплату менее 20тыс., не имея большой загруженности и не получив повышение за год. За сотрудником были замечены нарушения по трудовому договору. Оценка работы данного сотрудника, выставленная руководителем, равна 1 баллу. СТаж работы сотрудника на данной предприятии всего 1 год.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера  <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Приятно видеть общий вывод)

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# В ходе работы над проектом согласно поставленным задачам было построено две модели МО, полностью подходящие под задачи:
#   * Первая модель, которая сможет предсказать уровень удовлетворённости сотрудника на основе данных заказчика:
#     * **DecisionTreeRegressor** имеет следующие гиперпараметры:
#       * **max_depth=13**.
#       * **max_features=8**.
#     * Метрика **SMAPE** на тренировочной выборке **-15.93**.
#     * Метрика **SMAPE** на тестовой выборке **14.23**.
#   * Вторая модель, которая сможет на основе данных заказчика предсказать то, что сотрудник уволится из компании:
#     * **DecisionTreeClassifier** имеет следующие гиперпараметры:
#       * **max_depth=5**.
#       * **max_features=28**.
#     * Метрика **ROC-AUC** на тренировочной выборке **0.9**.
#     * Метрика **ROC-AUC** на тестовой выборке и **0,92**.
#
# ТАк же в ходе работы над проектом был построен портрет "уволившегося сотрудника":
#
# *Сотрудник работал в отделе technology, имея уровень квалификации junior, зарплату менее 20тыс., не имея большой загруженности и не получив повышение за год. За сотрудником были замечены нарушения по трудовому договору. Оценка работы данного сотрудника, выставленная руководителем, равна 1 баллу. СТаж работы сотрудника на данной предприятии всего 1 год.*

# %% [markdown]
# **Рекомендации**:
# Для повышения уровня удовлетворённости и понижения вероятности увольнений сотрудников рекомендуется:
# * Переписать систему карьерного роста, разработав чёткие критерии повышения по уровню занимаемой должности.
# * Выделить средства на повышение ЗП согласно стажу работы в компании.
# * Разработать систему равномерного распределения работы между сотрудниками.

# %% [markdown]
#  <div style="border:solid Chocolate 2px; padding: 40px">
#
#
# <h2> Итоговый комментарий ревьюера (общий вывод по проекту) <a class="tocSkip"> </h2>
#
#
# У меня сложилось хорошее общее впечатление о проекте, тебе удалось неплохо справиться с этим проектом. Молодец! Подготовлены данные для анализа, изучен каждый параметр. Все красиво визуализировано, построено несколько моделей регрессии/ классификации и оценено их качество. Осмысленная аналитика и дельная модельная работа - многое удалось как надо)
#
# Отмечу отдельные положительные моменты проекта🙂:
#
# - в ходе проекта встречались  функции, помогающие избавиться от дублирования кода;
# - много красивых визуализаций в проекте и хорошая интерпретация;
# - при обучении моделей использованы пайплайны, кросс-валидация и поиск гиперпараметров.
#
# Есть несколько моментов всего, на которые стоит ещё раз взглянуть, я указал их в моих комментариях по ходу проекта. Предлагаю тебе доработать проект по моим комментариям, чтобы довести его до совершенства.
#
#
#
# </div>

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>👋:</b> Спасибо за проверку моей работы и отделньое спасибо за рекомендации и советы! Я не стал изменять код после желтого комментария, чтобы не задерживаться на этом проекте, но обязательно учту это в будущих работах. Все красные замечания я поправил, надеюсь всё правильно.
#
# Если не против ответить, я хотел бы задать вопрос не по теме проекта. Перед началом этого проекта платформа задавала мне вопросы про работу саентиста вне платформы(про фриланс, например), а так же был мини-курс про "сложности в обучении. И вот мне стало интересно мнение специалиста, который уже работает в этой сфере. Скажи, пожалуйста, хватит ли моего уровня знаний для каких-то небольших проектом во фрилансе? А так же если "да", не подскажешь, какими площадками фриланса ты бы мог посоветовать воспользоваться? Ещё раз уточню, ответ на вопрос чисто добровольный, но очень интересен твой ответ.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Очень рад, что мои советы и комментарии тебе пригодились! 😊 Теперь к твоему вопросу.
#
# **Хватит ли твоего уровня для фриланса?**
# Судя по твоим вопросам и подходу к проектам, у тебя уже есть довольно хорошие базовые навыки:
# - Ты понимаешь, как работать с данными, включая их обработку и визуализацию.
# - Умеешь настраивать пайплайны, использовать модели, проводить анализ признаков и интерпретацию результатов.
# - Знаешь, как улучшать модели, работать с гиперпараметрами и их тюнингом.
#
# Для небольших фриланс-проектов этого достаточно! На фрилансе чаще всего ищут решения вполне прикладных задач:
# - Построить модель для предсказания чего-либо.
# - Создать отчёт, дашборд или визуализацию данных.
# - Провести исследование данных и сделать выводы.
#
# Для старта важно уверенно чувствовать себя в решении типичных задач. Если что-то сложное встретится, ты всегда можешь дополнительно изучить это в процессе.
#
# ---
#
# **С чего начать?**
# 1. **Портфолио.**
#    Если у тебя есть 2-3 законченных проекта, добавь их в портфолио. Желательно выбрать задачи из разных областей: классификация, регрессия, NLP или компьютерное зрение. Можно использовать платформы вроде GitHub, где ты опишешь свои проекты, покажешь код и сделаешь небольшие выводы.
#
# 2. **Небольшие проекты.**
#    Начни с задач, где ты чувствуешь уверенность. Например:
#    - Прогнозирование продаж.
#    - Анализ текстов (например, классификация отзывов).
#    - Визуализация данных или отчёт.
#
# 3. **Площадки для фриланса.**
#    Вот несколько популярных мест:
#    - **Upwork** — международная площадка с широким выбором задач, но конкуренция высокая.
#    - **Freelancer** — похожа на Upwork, но чуть менее строгая к новичкам.
#    - **Toptal** — для опытных специалистов, но можно пробовать, если уверена в себе.
#    - **FL.ru** — русскоязычная площадка. Здесь часто появляются аналитические задачи.
#    - **Каналы в Telegram** — есть чаты, где публикуют разовые задачи.
#
# 4. **Советы для первых заказов:**
#    - Ставь небольшую стоимость за работу, чтобы набрать первые отзывы.
#    - Всегда уточняй все детали задачи: данные, метрики успеха, сроки.
#    - Если проект слишком сложен, не бойся отказаться — лучше учиться на своих условиях, а не рисковать.
#
# ---
#
# **Советы напоследок**
# - **Не бойся делать ошибки.** Это нормально в начале пути.
# - **Учись презентовать свои результаты.** Умение донести выводы — важнейший навык.
# - **Развивай свои навыки.** Бери задачи чуть сложнее твоего уровня, чтобы расти.
#
# Ты определённо готова к фрилансу на небольших проектах. Смело пробуй! 😊
