# %% [markdown]
# # Проект: Обучение с учителем: качество модели

# %% [markdown]
# **Цель проекта** - разработать решение, которое позволит персонализировать предложения постоянным клиентам, чтобы увеличить их покупательскую активность.
#
# В распоряжении 4 датасета:
# * **market_file.csv** - содержит данные о поведении покупателя на сайте, о коммуникациях с покупателем и его продуктовом поведении:
#    * Описание даных:
#       * *`id`* — номер покупателя в корпоративной базе данных.
#       * *`Покупательская активность`* — рассчитанный класс покупательской активности (целевой признак): «снизилась» или «прежний уровень».
#       * *`Тип сервиса`* — уровень сервиса, например «премиум» и «стандарт».
#       * *`Разрешить сообщать`* — информация о том, можно ли присылать покупателю дополнительные предложения о товаре. Согласие на это даёт покупатель.
#       * *`Маркет_актив_6_мес`* — среднемесячное значение маркетинговых коммуникаций компании, которое приходилось на покупателя за последние 6 месяцев. Это значение показывает, какое число рассылок, звонков, показов рекламы и прочего приходилось на клиента.
#       * *`Маркет_актив_тек_мес`* — количество маркетинговых коммуникаций в текущем месяце.
#       * *`Длительность`* — значение, которое показывает, сколько дней прошло с момента регистрации покупателя на сайте.
#       * *`кционные_покупки`* — среднемесячная доля покупок по акции от общего числа покупок за последние 6 месяцев.
#       * *`Популярная_категория`* — самая популярная категория товаров у покупателя за последние 6 месяцев.
#       * *`Средний_просмотр_категорий_за_визит`* — показывает, сколько в среднем категорий покупатель просмотрел за визит в течение последнего месяца.
#       * *`Неоплаченные_продукты_штук_квартал`* — общее число неоплаченных товаров в корзине за последние 3 месяца.
#       * *`Ошибка_сервиса`* — число сбоев, которые коснулись покупателя во время посещения сайта.
#       * *`Страниц_за_визит`* — среднее количество страниц, которые просмотрел покупатель за один визит на сайт за последние 3 месяца.
#
# * **market_money.csv** - содержит данные о выручке, которую получает магазин с покупателя, то есть сколько покупатель всего потратил за период взаимодействия с сайтом:
#    * Описание данных:
#       * *`id`* — номер покупателя в корпоративной базе данных.
#       * *`Период`* — название периода, во время которого зафиксирована выручка. Например, 'текущий_месяц' или 'предыдущий_месяц'.
#       * *`Выручка`* — сумма выручки за период.
# * **market_time.csv** - содержит данные о времени (в минутах), которое покупатель провёл на сайте в течение периода:
#    * Описание данных:
#       * *`id`* — номер покупателя в корпоративной базе данных.
#       * *`Период`* —  название периода, во время которого зафиксировано общее время.
#       * *`минут`* — значение времени, проведённого на сайте, в минутах.
# * **money.csv** - содержит данные о среднемесячной прибыли покупателя за последние 3 месяца: какую прибыль получает магазин от продаж каждому покупателю:
#    * Описание данных:
#       * *`id`* — номер покупателя в корпоративной базе данных.
#       * *`Прибыль`* —  значение прибыли.
#
#
# **Цель исследования:**
# 1. Иследовательский анализ данных:
#    * Анализ данных каждой таблицы.
#    * Отбор клиентов с покупательской активностью не менее трёх месяцев.
#    * Выводы ооб анализе данных.
# 2. Объединение таблиц:
#    * Объединение таблиц **market_file.csv**, **market_money.csv** и **market_time.csv**.
#    * Создать отдельные столбцы с выручкой и временем на сайте для каждого периода в итоговой таблице.
# 3. Корреляционный анализ:
#    * Проведение корреляционного аналиаз признаков в количественной шкале в итоговой таблице для моделирования.
#    * Выводы о мультиколлинеарности.
# 4. Использование пайплайнов:
#    * Подготовка данных с использованием **ColumnTransformer**.
#    * Обучение четырёх моделей: **KNeighborsClassifier(), DecisionTreeClassifier(), LogisticRegression() и  SVC()**.
#    * Выбор лучшей модели.
# 5. Анализ важности признаков:
#    * Оценка важности признаков для лучшей модели и построение графика важности с помощью метода **SHAP**.
#    * Выводы о значимости признаков.
# 6. Сегментация покупателей:
#    * Сегментация пользователей.
#    * Выбор группы покупателей и предложение по увеличению покупательской активности.
#    * Выводы о сегментации.
#
# **Ход исследования**
# Данные мы получим из наборов данных:
# * *'/datasets/market_file.csv'*;
# * *'/datasets/market_money.csv'*;
# * *'/datasets/market_time.csv'*;
# * *'/datasets/money.csv'*.
#
# Нет информации о качестве данных, потому нужно провести изучение данных до того, как приступать к иcследованию. После изучения данных сделаем предобработку данных, устраняя все возможные ошибки, пропуски и дубликаты данных, чтобы они не искажали результаты исследований.
#
# Таким образом можно составить план исследования данных:
# 1. Загрузка и изучение данных;
# 2. Предобработка данных;
# 3. Иследовательский анализ данных;
# 4. Объединение таблиц;
# 5. Корреляционный анализ;
# 6. Использование пайплайнов;
# 7. Анализ важности признаков;
# 8. Сегментация покупателей;
# 9. Итоговые выводы по исследованиям.

# %% [markdown]
# ## Загрузка и изучение данных

# %% [markdown]
# ### Установка и импорт библиотек и инструментов

# %%
# Установим отсутствующие библиотеки
# !pip install scikit-learn==1.1.3
# !pip install shap -q
# !pip -q install phik

# %%
# Импортируем необъодимые библиотеки и инструменты
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
import numpy as np

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder, MinMaxScaler
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.metrics import roc_auc_score, f1_score

import shap

import phik

# %%
# Установим константы
RANDOM_STATE = 42
TEST_SIZE = 0.25

# %% [markdown]
# ### Загрузка данных

# %%
 # Загружаем данные с возможностью загрузить их с сервера в случае недоступности локальных файлов
try:
    market_file = pd.read_csv('/datasets/market_file.csv')
    market_money = pd.read_csv('/datasets/market_money.csv')
    market_time = pd.read_csv('/datasets/market_time.csv')
    money = pd.read_csv('/datasets/money.csv', sep=';', decimal=",")
except:
    market_file = pd.read_csv('https://***/datasets/market_file.csv')
    market_money = pd.read_csv('https://***/datasets/market_money.csv')
    market_time = pd.read_csv('https://***/datasets/market_time.csv')
    money = pd.read_csv('https://***/datasets/money.csv', sep=';', decimal=",")

# %% [markdown]
# ### Обзор данных

# %% [markdown]
# #### Датафрейм market_file

# %%
# Выводим первые 5 строк датафрейма
market_file.head()
# Out:
#        id Покупательская активность Тип сервиса Разрешить сообщать  \
# 0  215348                 Снизилась     премиум                 да
# 1  215349                 Снизилась     премиум                 да
# 2  215350                 Снизилась   стандартт                нет
# 3  215351                 Снизилась   стандартт                 да
# 4  215352                 Снизилась   стандартт                нет
#
#    Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  Акционные_покупки  \
# 0                 3.4                     5           121               0.00
# 1                 4.4                     4           819               0.75
# 2                 4.9                     3           539               0.14
# 3                 3.2                     5           896               0.99
# 4                 5.1                     3          1064               0.94
#
#   Популярная_категория  Средний_просмотр_категорий_за_визит  \
# ...

# %%
# Посмотрим общую информацию о датафрейме
market_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1300 non-null   int64
#  1   Покупательская активность            1300 non-null   object
#  2   Тип сервиса                          1300 non-null   object
#  3   Разрешить сообщать                   1300 non-null   object
#  4   Маркет_актив_6_мес                   1300 non-null   float64
#  5   Маркет_актив_тек_мес                 1300 non-null   int64
#  6   Длительность                         1300 non-null   int64
#  7   Акционные_покупки                    1300 non-null   float64
#  8   Популярная_категория                 1300 non-null   object
#  9   Средний_просмотр_категорий_за_визит  1300 non-null   int64
#  10  Неоплаченные_продукты_штук_квартал   1300 non-null   int64
# ...

# %%
# Охарактеризовываем числовые данные
market_file.drop('id', axis=1).describe().T
# Out:
#                                       count        mean         std    min  \
# Маркет_актив_6_мес                   1300.0    4.253769    1.014814    0.9
# Маркет_актив_тек_мес                 1300.0    4.011538    0.696868    3.0
# Длительность                         1300.0  601.898462  249.856289  110.0
# Акционные_покупки                    1300.0    0.319808    0.249843    0.0
# Средний_просмотр_категорий_за_визит  1300.0    3.270000    1.355350    1.0
# Неоплаченные_продукты_штук_квартал   1300.0    2.840000    1.971451    0.0
# Ошибка_сервиса                       1300.0    4.185385    1.955298    0.0
# Страниц_за_визит                     1300.0    8.176923    3.978126    1.0
#
#                                         25%     50%    75%      max
# Маркет_актив_6_мес                     3.70    4.20    4.9     6.60
# Маркет_актив_тек_мес                   4.00    4.00    4.0     5.00
# Длительность                         405.50  606.00  806.0  1079.00
# ...

# %% [markdown]
# **Выводы**: Датасет соответствует описанию. Пропусков не обнаружено. Названия некоторых столбцов содержат пробелы, это необходимо исправить во время предобработки данных.

# %% [markdown]
# #### Датафрейм market_money

# %%
# Выводим первые 5 строк датафрейма
market_money.head()
# Out:
#        id               Период  Выручка
# 0  215348  препредыдущий_месяц      0.0
# 1  215348        текущий_месяц   3293.1
# 2  215348     предыдущий_месяц      0.0
# 3  215349  препредыдущий_месяц   4472.0
# 4  215349        текущий_месяц   4971.6

# %%
# Посмотрим общую информацию о датафрейме
market_money.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3900 non-null   int64
#  1   Период   3900 non-null   object
#  2   Выручка  3900 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 91.5+ KB

# %%
# Охарактеризовываем числовые данные
market_money.drop('id', axis=1).describe()
# Out:
#              Выручка
# count    3900.000000
# mean     5025.696051
# std      1777.704104
# min         0.000000
# 25%      4590.150000
# 50%      4957.500000
# 75%      5363.000000
# max    106862.200000

# %% [markdown]
# **Выводы**: Датасет соответствует описанию. Пропусков не обнаружено. В глаза явно бросаются минимальное и максимальное значения выручки. Необходимо проверить во время анализа данных.

# %% [markdown]
# #### Датафрейм market_time

# %%
# Выводим первые 5 строк датафрейма
market_time.head()
# Out:
#        id            Период  минут
# 0  215348     текущий_месяц     14
# 1  215348  предыдцщий_месяц     13
# 2  215349     текущий_месяц     10
# 3  215349  предыдцщий_месяц     12
# 4  215350     текущий_месяц     13

# %%
# Посмотрим общую информацию о датафрейме
market_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2600 non-null   int64
#  1   Период  2600 non-null   object
#  2   минут   2600 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 61.1+ KB

# %%
# Охарактеризовываем числовые данные
market_time.drop('id', axis=1).describe()
# Out:
#              минут
# count  2600.000000
# mean     13.336154
# std       4.080198
# min       4.000000
# 25%      10.000000
# 50%      13.000000
# 75%      16.000000
# max      23.000000

# %% [markdown]
# **Выводы**: Датасет соответствует описанию. Пропусков не обнаружено. Замечены явные ошибки в названии периода. Необходимо проверить на неявные дубликаты во время предобработки данных.

# %% [markdown]
# #### Датафрейм money

# %%
# Выводим первые 5 строк датафрейма
money.head()
# Out:
#        id  Прибыль
# 0  215348     0.98
# 1  215349     4.16
# 2  215350     3.13
# 3  215351     4.87
# 4  215352     4.21

# %%
# Посмотрим общую информацию о датафрейме
money.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1300 non-null   int64
#  1   Прибыль  1300 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 20.4 KB

# %%
# Охарактеризовываем числовые данные
money.drop('id', axis=1).describe()
# Out:
#            Прибыль
# count  1300.000000
# mean      3.996631
# std       1.013722
# min       0.860000
# 25%       3.300000
# 50%       4.045000
# 75%       4.670000
# max       7.430000

# %% [markdown]
# **Выводы**: Датасет соответствует описанию. Пропусков не обнаружено.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# **План предобработки данных:**
# * [x] Переименовать столбцы.
# * [x] Проверить и исправить дубликаты.
# * [x] Проверить и исправить пропуски.
# * [x] Проверить и исправить выбросы.

# %% [markdown]
# ### Переименовывание столбцов

# %%
# Переименуем названия столбцов в датафрейме market_file
market_file.columns = market_file.columns.str.replace(' ', '_').str.lower()

# %%
# Проверим столбцы
market_file.columns
# Out:
# Index(['id', 'покупательская_активность', 'тип_сервиса', 'разрешить_сообщать',
#        'маркет_актив_6_мес', 'маркет_актив_тек_мес', 'длительность',
#        'акционные_покупки', 'популярная_категория',
#        'средний_просмотр_категорий_за_визит',
#        'неоплаченные_продукты_штук_квартал', 'ошибка_сервиса',
#        'страниц_за_визит'],
#       dtype='object')

# %%
# Переименуем названия столбцов в датафрейме market_money
market_money.columns = market_money.columns.str.lower()

# %%
# Проверим столбцы
market_money.columns
# Out:
# Index(['id', 'период', 'выручка'], dtype='object')

# %%
# Переименуем названия столбцов в датафрейме market_time
market_time.columns = market_time.columns.str.lower()

# %%
# Проверим столбцы
market_time.columns
# Out:
# Index(['id', 'период', 'минут'], dtype='object')

# %%
# Переименуем названия столбцов в датафрейме money
money.columns = money.columns.str.lower()

# %%
# Проверим столбцы
money.columns
# Out:
# Index(['id', 'прибыль'], dtype='object')

# %% [markdown]
# **Вывод**: Все столбцы переименованы. Пробелы заменены на символ "_", а так же все символы приведены в нижний регистр.

# %% [markdown]
# ### Дубликаты

# %%
# Проверим датафрейм market_file на наличие дубликатов
market_file.duplicated().sum()
# Out:
# 0

# %%
# Проверим столбец "тип_сервиса" на наличие неявных дубликатов
market_file['тип_сервиса'].sort_values().unique()
# Out:
# array(['премиум', 'стандарт', 'стандартт'], dtype=object)

# %%
# Исправим дубликаты
market_file['тип_сервиса'] = market_file['тип_сервиса'].replace({'стандартт': 'стандарт'})

# %%
# Проверим датафрейм market_money на наличие дубликатов
market_money.duplicated().sum()
# Out:
# 0

# %%
# Проверим столбец "период" на наличие неявных дубликатов
market_money['период'].sort_values().unique()
# Out:
# array(['предыдущий_месяц', 'препредыдущий_месяц', 'текущий_месяц'],
#       dtype=object)

# %%
# Проверим датафрейм market_time на наличие дубликатов
market_time.duplicated().sum()
# Out:
# 0

# %%
# Проверим столбец "период" на наличие неявных дубликатов
market_time['период'].sort_values().unique()
# Out:
# array(['предыдцщий_месяц', 'текущий_месяц'], dtype=object)

# %%
# Исправим ошибку в названии периода
market_time['период'] = market_time['период'].replace({'предыдцщий_месяц': 'предыдущий_месяц'})

# %%
# Проверим датафрейм money на наличие дубликатов
money.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Вывод**: Все дубликаты проверены. В датафрейме *`market_file`* найдены и исправлены неявные дубликаты. В датафрейме *`market_time`* найдены и исправлены ошибки в названии периода во избежании возможного возникновения ошибочных данных в объединении датафреймов.

# %% [markdown]
# ### Пропуски

# %%
# Проверим все датафреймы на наличие пропусков
market_file.isna().sum()
# Out:
# id                                     0
# покупательская_активность              0
# тип_сервиса                            0
# разрешить_сообщать                     0
# маркет_актив_6_мес                     0
# маркет_актив_тек_мес                   0
# длительность                           0
# акционные_покупки                      0
# популярная_категория                   0
# средний_просмотр_категорий_за_визит    0
# неоплаченные_продукты_штук_квартал     0
# ошибка_сервиса                         0
# страниц_за_визит                       0
# dtype: int64

# %%
market_money.isna().sum()
# Out:
# id         0
# период     0
# выручка    0
# dtype: int64

# %%
market_time.isna().sum()
# Out:
# id        0
# период    0
# минут     0
# dtype: int64

# %%
money.isna().sum()
# Out:
# id         0
# прибыль    0
# dtype: int64

# %% [markdown]
# **Вывод**: Все датафреймы проверены, пропусков не обнаружено.

# %% [markdown]
# ### Выбросы

# %% [markdown]
# Ранее были замечены выбросы в датафрейме market_money. Проверим их.

# %%
# Посмотрим на "ящик с усами" по столбцу "выручка"
market_money.boxplot('выручка', figsize=(5, 5));

# %%
# Посмотрим на верхний выброс
market_money.query('выручка > 20000')
# Out:
#         id         период   выручка
# 98  215380  текущий_месяц  106862.2

# %%
# Проверим информацию о данном покупателе в основном датафрейме
market_file.query('id == 215380')
# Out:
#         id покупательская_активность тип_сервиса разрешить_сообщать  \
# 32  215380                 Снизилась     премиум                нет
#
#     маркет_актив_6_мес  маркет_актив_тек_мес  длительность  акционные_покупки  \
# 32                 1.7                     4           637               0.94
#
#               популярная_категория  средний_просмотр_категорий_за_визит  \
# 32  Техника для красоты и здоровья                                    3
#
#     неоплаченные_продукты_штук_квартал  ошибка_сервиса  страниц_за_визит
# 32                                   2               4                 7

# %% [markdown]
# Выброс единичный и выглядит как аномалия, т.к. больше среднего примерно в 20 раз. Заменим его на медианное значение от остальных данных.

# %%
market_money.loc[market_money['id'] == 215380, 'выручка'] = market_money['выручка'].median()

# %%
# Еще раз посмотрим на "ящик с усами" по столбцу "выручка"
market_money.boxplot('выручка', figsize=(5, 5));

# %%
# Посмотрим на нижние выбросы
market_money.query('выручка < 2000')
# Out:
#         id               период  выручка
# 0   215348  препредыдущий_месяц      0.0
# 2   215348     предыдущий_месяц      0.0
# 28  215357  препредыдущий_месяц      0.0
# 29  215357     предыдущий_месяц      0.0
# 34  215359     предыдущий_месяц      0.0
# 35  215359  препредыдущий_месяц      0.0

# %%
# Проверим информацию о данных покупателях в основном датафрейме
market_file.query('id == (215348, 215357, 215359)')
# Out:
#         id покупательская_активность тип_сервиса разрешить_сообщать  \
# 0   215348                 Снизилась     премиум                 да
# 9   215357                 Снизилась    стандарт                 да
# 11  215359                 Снизилась    стандарт                 да
#
#     маркет_актив_6_мес  маркет_актив_тек_мес  длительность  акционные_покупки  \
# 0                  3.4                     5           121                0.0
# 9                  3.9                     5           154                0.0
# 11                 4.6                     5           110                0.0
#
#               популярная_категория  средний_просмотр_категорий_за_визит  \
# 0                 Товары для детей                                    6
# 9   Техника для красоты и здоровья                                    3
# 11               Домашний текстиль                                    4
#
#     неоплаченные_продукты_штук_квартал  ошибка_сервиса  страниц_за_визит
# ...

# %% [markdown]
# **Вывод**: Все выбросы проверены. Т.к. верхний выброс единичный и похож на аномалию, решено заменить его значение медианным. Нижние выбросы не единичны, похоже на пользователей магазина, ни разу ничего не покупавших, решено временно оставить как есть.

# %% [markdown]
# ### Выводы по предобработке данных

# %% [markdown]
# Во время предобработки данных было сделано:
# * Столбцы всех датафреймов приведены в единый стиль.
# * Все дубликаты проверены:
#    * В датафрейме *`market_file`* найдены и исправлены неявные дубликаты.
#    * В датафрейме *`market_time`* найдены и исправлены ошибки в названии периода.
#    * В остальных датафреймах дубликатов не обнаружено.
# * Во всех датафреймах проверены пропуски. Пропусков не обнаружено.
# * Все выбросы проверены:
#    * В датафрейме *`market_money`* найдена аномалия в виде **выручки** в размере **106862.2**. Аномалия заменена на медианное значение выручки.
#    * В датафрейме *`market_money`* проверены выбросы в виде **нулевой выручки**. После проверки решено временно оставить, как есть.

# %% [markdown]
# ## Исследовательский анализ данных

# %%
# Подготовим несколько функций для убодства анализа данных

# Построение субплота с гистограммой и "ящика с усами" внутри
def hist_with_wiskers(data, column, target):
    sns.set()
    f, axes = plt.subplots(1, 2, figsize=(20, 4))
    axes[0].set_title(f'Гистограмма для {column}', fontsize=16)
    axes[0].set_ylabel('Количество', fontsize=14)
    if target != None:
        sns.histplot(data, bins=20, kde=True, ax=axes[0], hue=target, x=column)
    else:
        sns.histplot(data, bins=20, kde=True, ax=axes[0], x=column)
    axes[1].set_title(f'"Ящик с усами" для {column}', fontsize=16)
    sns.boxplot(data=data, ax=axes[1], y=column)
    axes[1].set_ylabel(column, fontsize=14)
    plt.show()

# Построение отдельной гистограммы
def histogram(data, column, target):
    plt.figure(figsize=(8,6))
    plot = sns.histplot(data, bins=20, kde=True, hue=target, x=column)
    plot.set_title(f'Рапределение по {column}', fontsize=16)
    plot.set_ylabel('Количество', fontsize=14)

# Построение суммарной столбчатой диаграммы по сводной таблице
def pivot_bar_plot(data, column):
    plt.figure(figsize=(8,6))
    plot = sns.barplot(x=column, data=data, y=data.index)
    plot.set_title(f'Рапределение по {column}', fontsize=16)
    plot.set_xlabel('Количество', fontsize=14)

# Построение количественной столбчатой диаграммы
def categoral_unique(data, column):
    plt.figure(figsize=(8,6))
    plot = sns.countplot(y=column, data=data)
    plot.set_title(f'Рапределение по {column}', fontsize=16)
    plot.set_xlabel('Количество', fontsize=14)

# Построение субплота из круговых диаграмм
def pie_graph(data, column, name, n, i):
    plt.subplot(1, n, i)
    plt.title(column)
    plt.pie(x=data.groupby(column)[name].count(),
            startangle=90,
            labeldistance=1.1,
            wedgeprops={'linewidth':3, 'edgecolor':'white'},
            autopct='%1.1f%%',
            labels=data.groupby(column)[name].count().index)

# %% [markdown]
# ### Датафрейм market_file

# %%
# Проверим количественное распределение по покупательской активности
categoral_unique(market_file, 'покупательская_активность')

# %% [markdown]
# Пользователей с прежним уровнем активности на много больше, чем пользователей с понизевшейся активностью. Нужно будет учесть при построении модели.

# %%
# Проверим количественное распределение по уровню сервиса
categoral_unique(market_file, 'тип_сервиса')

# %% [markdown]
# Пользователей со стандартным уровнем сервиса на много больше, чем пользователей с премиальным уровнем сервиса. Нужно будет учесть при построении модели.

# %%
# Проверим количественное распределение по популярным категориям
categoral_unique(market_file, 'популярная_категория')

# %% [markdown]
# Самая популярная категория товаров у пользователей - **Товары для детей**, самая непопулярная же категория - **Кухонная посуда**.

# %%
# Посмотрим на распределение просмотренных страниц за визит относительно активности
hist_with_wiskers(market_file, 'страниц_за_визит', 'покупательская_активность')

# %% [markdown]
# Как и ожидалось, пользователей с пониженной активностью просматривают меньше страниц за один визит.

# %%
# Посмотрим на распределение ошибок сервиса относительно активности
hist_with_wiskers(market_file, 'ошибка_сервиса', 'покупательская_активность')

# %% [markdown]
# Распределение в целом схожее. Странно то, что сервис вообще выдаёт столько ошибок. **Возможно стоит поработать над технической стабильностью сервиса?**

# %%
# Посмотрим на распределение неоплаченных товаров относительно активности
hist_with_wiskers(market_file, 'неоплаченные_продукты_штук_квартал', 'покупательская_активность')

# %% [markdown]
# Как и ожидалось, пользователи с пониженной активностью чаще не выкупают товар.

# %%
# Посмотрим на распределение просмотренных категорий за визит относительно активности
hist_with_wiskers(market_file, 'средний_просмотр_категорий_за_визит', 'покупательская_активность')

# %% [markdown]
# Как и ожидалось, пользователи с пониженной активностью просматривают меньше категорий за визит.

# %% [markdown]
# ### Датафрейм market_money

# %%
# Построим сводную таблицу выручки по периодам
data_temp = market_money.pivot_table(index='период', values=['выручка'], aggfunc='sum')

# %%
# Посмотрим на созданную сводную таблицу
data_temp.sort_values(by='выручка')
# Out:
#                        выручка
# период
# препредыдущий_месяц  6272675.5
# предыдущий_месяц     6416877.0
# текущий_месяц        6807544.4

# %%
# Построим столбчатую диаграмму распределения выручки сервиса по периодам
pivot_bar_plot(data_temp, 'выручка')

# %%
# Посмотрим на гистограмму и "ящик с усами" выручки сервиса
hist_with_wiskers(market_money, 'выручка', None)

# %% [markdown]
# В целом выручка сервиса растёт с каждым месяцем, но не существенно относительно предыдущего месяца. Распределение выручки выглядит ровным, не считая тех выбросов с пользоваателями с нулевой выручкой.

# %% [markdown]
# ### Датафрейм market_time

# %%
# Построим сводную таблицу проведённого пользователями на сервисе времени по периодам
data_temp = market_time.pivot_table(index='период', values=['минут'], aggfunc='sum')

# %%
# Посмотрим на созданную сводную таблицу
data_temp.sort_values(by='минут')
# Out:
#                   минут
# период
# текущий_месяц     17166
# предыдущий_месяц  17508

# %%
# Построим столбчатую диаграмму распределения проведённого пользователями на сервисе времени по периодам
pivot_bar_plot(data_temp, 'минут')

# %%
# Посмотрим на гистограмму и "ящик с усами" проведённого пользователями на сервисе времени
hist_with_wiskers(market_time, 'минут', None)

# %% [markdown]
# Общее время, проведённое пользователями на сервисе в целом равны за оба периода. Распределение в целом выглядит нормальным, без каких либо выбросов.

# %% [markdown]
# ### Датафрейм money

# %%
# Посмотрим на гистограмму и "ящик с усами" прибыли сервиса
hist_with_wiskers(money, 'прибыль', None)

# %% [markdown]
# В целом распределение прибыли сервиса выглядит нормально, без каких-либо значимых выбросов.

# %% [markdown]
# ### Отбор активных пользователей

# %% [markdown]
# Активными пользователями можно считать тех, кто приносил какую-либо выручку сервису за последние три месяца. Решено обновить имеющиеся датафреймы, удалив те самые выбросы с нулевой выручкой из всех датафреймов.

# %%
# Посмотрим список id пользователей с нулевой выручкой
market_money.loc[market_money['выручка'] == 0, 'id'].unique()
# Out:
# array([215348, 215357, 215359])

# %%
# Удалим пользователей с нулевой выручкой из всех датафреймов
market_file = market_file.query('id != [215348, 215357, 215359]')
market_money = market_money.query('id != [215348, 215357, 215359]')
market_time = market_time.query('id != [215348, 215357, 215359]')
money = money.query('id != [215348, 215357, 215359]')

# %% [markdown]
# ### Выводы по исследовательскому анализу данных

# %% [markdown]
# Согласно исследовательскому анализу данных был выявлен дисбаланс в таких признаках, как *`покупательская_активность`* и *`тип_сервиса`*. Распределение всех численных признаков выглядит нормально. Для дальнейшей работы были выбраны только активные пользователи путём удаления выбросов с нулевой выручкой. Таким образом было удалено 3 пользователя из всех датафреймов.

# %% [markdown]
# ## Объединение таблиц

# %%
# Разделим датафрейм market_money по периодам
market_money_pivot = market_money.pivot_table(index=['id'], columns=["период"])
market_money_pivot.columns = ['предыдущий_месяц_выручка', 'препредыдущий_месяц_выручка', 'текущий_месяц_выручка']
market_money_pivot['id'] = market_money_pivot.index

# %%
# Проверим новую таблицу
market_money_pivot.head()
# Out:
#         предыдущий_месяц_выручка  препредыдущий_месяц_выручка  \
# id
# 215349                    5216.0                       4472.0
# 215350                    5457.5                       4826.0
# 215351                    6158.0                       4793.0
# 215352                    5807.5                       4594.0
# 215353                    4738.5                       5124.0
#
#         текущий_месяц_выручка      id
# id
# 215349                 4971.6  215349
# 215350                 5058.4  215350
# 215351                 6610.4  215351
# 215352                 5872.5  215352
# 215353                 5388.5  215353

# %%
# Точно так же разделим датафрейм market_time
market_time_pivot = market_time.pivot_table(index=['id'], columns=["период"])
market_time_pivot.columns = ['предыдущий_месяц_минут', 'текущий_месяц_минут']
market_time_pivot['id'] = market_time_pivot.index

# %%
market_time_pivot.head()
# Out:
#         предыдущий_месяц_минут  текущий_месяц_минут      id
# id
# 215349                      12                   10  215349
# 215350                       8                   13  215350
# 215351                      11                   13  215351
# 215352                       8                   11  215352
# 215353                      10                   10  215353

# %%
# Проверим датафреймы на количество строк перед объединением
market_file.shape
# Out:
# (1297, 13)

# %%
market_money_pivot.shape
# Out:
# (1297, 4)

# %%
market_time_pivot.shape
# Out:
# (1297, 3)

# %%
# Объединяем фатафреймы market_file, market_money и market_time
market = market_file.join(market_money_pivot, on='id', lsuffix="_left", rsuffix="_выручка")
market = market.rename(columns={'id_left':'id'})
market = market.join(market_time_pivot, on='id', lsuffix="_left", rsuffix="_минут")
market = market.rename(columns={'id_left':'id'})
market = market.drop(['id_выручка', 'id_минут'], axis=1)

# %%
# Проверим получившийся датафрейм
market.head()
# Out:
#        id покупательская_активность тип_сервиса разрешить_сообщать  \
# 1  215349                 Снизилась     премиум                 да
# 2  215350                 Снизилась    стандарт                нет
# 3  215351                 Снизилась    стандарт                 да
# 4  215352                 Снизилась    стандарт                нет
# 5  215353                 Снизилась    стандарт                 да
#
#    маркет_актив_6_мес  маркет_актив_тек_мес  длительность  акционные_покупки  \
# 1                 4.4                     4           819               0.75
# 2                 4.9                     3           539               0.14
# 3                 3.2                     5           896               0.99
# 4                 5.1                     3          1064               0.94
# 5                 3.3                     4           762               0.26
#
#   популярная_категория  средний_просмотр_категорий_за_визит  \
# ...

# %%
# Проверим количество строк в новом датафрейме
market.shape
# Out:
# (1297, 18)

# %%
# Проверим датафрейм на наличие пропусков
market.isna().sum()
# Out:
# id                                     0
# покупательская_активность              0
# тип_сервиса                            0
# разрешить_сообщать                     0
# маркет_актив_6_мес                     0
# маркет_актив_тек_мес                   0
# длительность                           0
# акционные_покупки                      0
# популярная_категория                   0
# средний_просмотр_категорий_за_визит    0
# неоплаченные_продукты_штук_квартал     0
# ошибка_сервиса                         0
# страниц_за_визит                       0
# предыдущий_месяц_выручка               0
# препредыдущий_месяц_выручка            0
# текущий_месяц_выручка                  0
# предыдущий_месяц_минут                 0
# текущий_месяц_минут                    0
# dtype: int64

# %%
# Проверим датафрейм на наличие дубликатов
market.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Выводы по объединению таблиц**: Таблицы успешно объеденины. Количество строк осталось прежним. Новых дубликатов и пропусков не обнаружено.

# %% [markdown]
# ## Корреляционный анализ данных

# %%
# Строим матрицу корреляций в виде тепловой карты
plt.figure(figsize=(15, 8))
sns.heatmap(market.phik_matrix(), annot=True)
plt.title("Тепловая карта корреляции")
plt.show()
# Out:
# interval columns not set, guessing: ['id', 'маркет_актив_6_мес', 'маркет_актив_тек_мес', 'длительность', 'акционные_покупки', 'средний_просмотр_категорий_за_визит', 'неоплаченные_продукты_штук_квартал', 'ошибка_сервиса', 'страниц_за_визит', 'предыдущий_месяц_выручка', 'препредыдущий_месяц_выручка', 'текущий_месяц_выручка', 'предыдущий_месяц_минут', 'текущий_месяц_минут']

# %% [markdown]
# По матрице корреляции можно видеть:
# * *`Покупательская активность`* имеет:
#   * <u>***Высокую связь***</u> с *`страниц_за_визит`*.
#   * <u>***Заметную связь***</u> с *`маркет_актив_6_мес`*, *`акционные_покупки`*, *`средний_просмотр_категории_за_визит`*, *`неоплаченные_продукты_штук_квартал`*, *`препредыдущий_месяц_выручка`*, *`предыдущий месяц_минут`* и *`текущий_месяц_минут`*.
#
# Так же <u>***Корреляционная связь отсутствует***</u> с *`разрешить_сообщать`* и *`маркет_актив_тек_мес`*.

# %% [markdown]
# **Мультиколлинеарность** между признаками <u>**отсутствует**</u>, однако связь между признаками *`текущий_месяц_выручка`* и *`препредыдущий_месяц_выручка`* **высокая**, стоит обратить на это внимание при построении модели.

# %% [markdown]
# ## Использование пайплайнов

# %% [markdown]
# ### Подготовка даных

# %%
# Закодируем целевой признак
# 1 = "Снизилась", 0 = "Прежний уровень"
market['покупательская_активность'] = market['покупательская_активность']\
.apply( lambda x: 1 if x=='Снизилась' else 0 )
market['покупательская_активность'] = market['покупательская_активность'].astype(int)

# %%
# Закодируем признак "акционные_покупки" в бинарный категориальный
market['акционные_покупки_по_категориям'] = market['акционные_покупки']\
.apply( lambda x: 'Покупает по акции' if x>= 0.5 else 'Не покупает по акции' )
market = market.drop(['акционные_покупки'], axis=1)

# %%
# Избавимся от столбца id, преобразив его в индекс датафрейма
market = market.set_index('id')

# %%
# Проверим датафрейм
market.head()
# Out:
#         покупательская_активность тип_сервиса разрешить_сообщать  \
# id
# 215349                          1     премиум                 да
# 215350                          1    стандарт                нет
# 215351                          1    стандарт                 да
# 215352                          1    стандарт                нет
# 215353                          1    стандарт                 да
#
#         маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# id
# 215349                 4.4                     4           819
# 215350                 4.9                     3           539
# 215351                 3.2                     5           896
# 215352                 5.1                     3          1064
# 215353                 3.3                     4           762
#
#        популярная_категория  средний_просмотр_категорий_за_визит  \
# id
# 215349     Товары для детей                                    4
# ...

# %%
# Сохраним выборки
X = market.drop(['покупательская_активность'], axis=1)
y = market['покупательская_активность']

# %%
# Разделим датафрейм на тренировочную и тестовую выборки
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size = TEST_SIZE,
    random_state = RANDOM_STATE,
    stratify = y
)

# %%
# Созадим списки категориальных и числовых признаков
ohe_columns = ['разрешить_сообщать', 'популярная_категория', 'тип_сервиса']
ord_columns = ['акционные_покупки_по_категориям']
num_columns = ['маркет_актив_6_мес', 'маркет_актив_тек_мес', 'маркет_актив_тек_мес',
               'длительность', 'средний_просмотр_категорий_за_визит',
               'неоплаченные_продукты_штук_квартал', 'ошибка_сервиса', 'страниц_за_визит',
               'предыдущий_месяц_выручка', 'препредыдущий_месяц_выручка', 'текущий_месяц_выручка',
               'предыдущий_месяц_минут', 'текущий_месяц_минут']

# %% [markdown]
# ### Подготовка пайплайнов

# %%
# OneHotEncoder-кодирование
ohe_pipe = Pipeline(
    [
        ('simpleImputer_ohe', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
        ('ohe', OneHotEncoder(handle_unknown='error', sparse=False))
    ]
)

# %%
# OrdinalEncoder-кодирование
ord_pipe = Pipeline(
    [
        (
            'simple_imputer_ord_before',
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        ),
        (
            'ord',
            OrdinalEncoder(categories=[
                                      ['Покупает по акции','Не покупает по акции']],
                          handle_unknown='use_encoded_value',
                          unknown_value=np.nan)
        ),
        (
            'simple_imputer_ord_after',
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        )
    ]
)

# %%
# Подготовка данных
data_preprocessor = ColumnTransformer(
    [('ohe', ohe_pipe, ohe_columns),
     ('ord', ord_pipe, ord_columns),
     ('num', MinMaxScaler(), num_columns)],
    remainder='passthrough'
)

# %%
# Финальный пайплайн
pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', DecisionTreeClassifier(random_state=RANDOM_STATE))
])

# %% [markdown]
# ### Подбор лучшей модели и гиперпараметров

# %%
# Задаём словари моделей для подбора моделей
param_grid = [
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': range(2,10),
        'models__max_features': range(2,10),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    },

    {
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': range(1,20),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    },

    {
        'models': [LogisticRegression(
            random_state=RANDOM_STATE,
            solver='liblinear',
            penalty='l1'
        )],
        'models__C': range(1,10),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    },

    {
        'models': [SVC(random_state=RANDOM_STATE, kernel='poly')],
        'models__degree': range(2,10),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    }
]

# %% [markdown]
# Метрику используем **roc-auc**, т.к. она лучше всего подходит под наши задачи. Метрика универсальна и её можно использовать для сравнения моделей с разными параметрами. Так же в данных присутствует дисбаланс классов, на которые данная метрика не будет обращать внимания.

# %%
# Для переборки гиперпараметров используем случайный подбор

randomized_search = RandomizedSearchCV(
    pipe_final,
    param_grid,
    cv=5,
    scoring='roc_auc',
    random_state=RANDOM_STATE,
    n_jobs=-1
)

# %%
# Ищем лучшую модель и гиперпараметры для неё
randomized_search.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('ohe',
#                                                                                Pipeline(steps=[('simpleImputer_ohe',
#                                                                                                 SimpleImputer(strategy='most_frequent')),
#                                                                                                ('ohe',
#                                                                                                 OneHotEncoder(sparse=False))]),
#                                                                                ['разрешить_сообщать',
#                                                                                 'популярная_категория',
# ...

# %%
print('Метрика roc_auc для лучшей модели:\n', randomized_search.best_score_)
print('\nЛучшая модель и её параметры:\n\n', randomized_search.best_estimator_)
# Out:
# Метрика roc_auc для лучшей модели:
#  0.8959586677586678
#
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(sparse=False))]),
#                                                   ['разрешить_сообщать',
#                                                    'популярная_категория',
#                                                    'тип_сервиса']),
#                                                  ('ord',
# ...

# %%
y_test_pred = randomized_search.predict_proba(X_test)

# %%
print(f'Метрика ROC-AUC на тестовой выборке: {roc_auc_score(y_test, y_test_pred[:,1])}')
# Out:
# Метрика ROC-AUC на тестовой выборке: 0.9212405713368642

# %% [markdown]
# ### Вывод

# %% [markdown]
# Лучшая модель получилась **LogisticRegression** с гиперпараметром **C=6**. Метрика **ROC-AUC** на тестовой выборке оказалась лучше, чем на тренировочной(**0.92 и 0.9**).

# %% [markdown]
# ## Анализ важности признаков

# %%
# Построим  графики важности признаков
X_encoded = randomized_search.best_estimator_['preprocessor'].fit_transform(X_train)
model = randomized_search.best_estimator_['models'].fit(X_encoded, y_train)
explainer = shap.LinearExplainer(model, X_encoded)
feature_names = randomized_search.best_estimator_[:-1].get_feature_names_out()
X_encoded = pd.DataFrame(X_encoded, columns=feature_names)
shap_values = explainer(X_encoded)

display(shap.plots.beeswarm(shap_values, max_display=15))
shap.summary_plot(shap_values, plot_type='bar', feature_names=feature_names)
# Out:
# None

# %% [markdown]
# Самые важные признаки:
# * *`средний_просмотр_категорий_за_визит`*.
# * *`тип_сервиса`*.
# * *`страниц_за_визит`*.
# * *`предыдущий_месяц_минут`*.
# * *`неоплаченные_продукты_штук_квартал`*.
#
# Чем выше значение признаков *`средний_просмотр_категорий_за_визит`*, *`страниц_за_визит`* и *`предыдущий_месяц_минут`*, тем ниже вероятность того, что *`покупательская_активность`* снизится. Так же можно заметить, что чем больше *`неоплаченные_продукты_штук_квартал`*  - тем больше вероятность, что *`покупательская_активность`* снизится. Пользователи с *`тип_Сервиса`* равным *премиум* реже имеют сниженную *`покупательская_активность`*, чем со значением *стандарт*.

# %% [markdown]
# ## Сегментация покупателей

# %% [markdown]
# Для сегментирования покупателей необходимо определиться с порогами, по которым пользователи будут разделены на сегменты.

# %%
# добавим к данным пользователей их вероятность того, что их *`покупательская_активность`* снизится
X_test['вероятность'] = y_test_pred[:, 1]
df = X_test.sort_values(by='вероятность')

# %%
# Добавим в датафрейм дополнительный датафрейм с прибылью пользователей
df = df.merge(money, on='id', how='left')

# %%
# Проверим новый датафрейм
df.head()
# Out:
#        id тип_сервиса разрешить_сообщать  маркет_актив_6_мес  \
# 0  215775    стандарт                нет                 5.0
# 1  216410     премиум                 да                 4.8
# 2  216273     премиум                 да                 5.7
# 3  216070     премиум                 да                 3.9
# 4  215838    стандарт                нет                 6.3
#
#    маркет_актив_тек_мес  длительность                  популярная_категория  \
# 0                     4           157  Мелкая бытовая техника и электроника
# 1                     3           939                     Домашний текстиль
# 2                     3           503                      Товары для детей
# 3                     4           379  Мелкая бытовая техника и электроника
# 4                     4           582                 Косметика и аксесуары
#
#    средний_просмотр_категорий_за_визит  неоплаченные_продукты_штук_квартал  \
# ...

# %%
# Создадим список столбцов датафрейма с числовыми данными
num_col = ['маркет_актив_6_мес', 'маркет_актив_тек_мес',
           'длительность',
           'средний_просмотр_категорий_за_визит',
           'неоплаченные_продукты_штук_квартал',
           'ошибка_сервиса', 'страниц_за_визит',
           'предыдущий_месяц_выручка',
           'препредыдущий_месяц_выручка',
           'текущий_месяц_выручка',
           'предыдущий_месяц_минут',
           'текущий_месяц_минут',
           'прибыль']

# %%
# Построим scatter plot для каждого числового столбца в зависимости от вероятности
for col in num_col:
    plt.figure(figsize=(12, 6))
    plt.title(f'Признак "{col}"')
    plt.xlabel('Вероятность снижения активности')
    plt.ylabel(f'Значение')
    plt.scatter(x=df['вероятность'],
                y=df[col],
                alpha=0.5)

# %% [markdown]
# Согласно графикам можно поставить следующие пороги для сегментирования. Покупательская активность снизится, если следующие показатели будут иметь такие значения:
# * *`маркет_актив_6_мес`* ниже 4.
# * *`средний_просмотр_категорий_за_визит`* ниже 4.
# * *`страниц_за_визит`* ниже 7.
#
# Для остальных признаков пороги не однозначны.

# %%
# Составим датафрейм с пользователями с большой
# вероятностью снижения активности согласно выбранным порогам
data = df.query('маркет_актив_6_мес < 4 and средний_просмотр_категорий_за_визит < 4 and страниц_за_визит < 7')

# %%
data.head()
# Out:
#          id тип_сервиса разрешить_сообщать  маркет_актив_6_мес  \
# 142  216317    стандарт                 да                 3.9
# 227  215566     премиум                 да                 2.4
# 228  215715     премиум                 да                 3.6
# 233  215477    стандарт                нет                 1.7
# 243  215542    стандарт                нет                 3.4
#
#      маркет_актив_тек_мес  длительность                  популярная_категория  \
# 142                     4           465  Мелкая бытовая техника и электроника
# 227                     4           785                      Товары для детей
# 228                     5           873                      Товары для детей
# 233                     4           377                      Товары для детей
# 243                     4           622                 Косметика и аксесуары
#
#      средний_просмотр_категорий_за_визит  неоплаченные_продукты_штук_квартал  \
# ...

# %%
# Посмотрим на распределение клоичественных признаков
for col in num_col:
    hist_with_wiskers(data, col, None)

# %%
# Составим список категориальных признаков
cat_col = ['тип_сервиса', 'разрешить_сообщать', 'акционные_покупки_по_категориям', 'популярная_категория']

# %%
# Построим круговые диаграммы категориальных признаков
i = 1
plt.figure(figsize=(18,6))
for col in cat_col:
    pie_graph(data, col, 'маркет_актив_6_мес', len(cat_col), i)
    i += 1

# %% [markdown]
# Исходя из графиков сильно выделяется то, что очень часто сервис выдаёт ошибку у этого сегмента пользователей. **Рекомендуется** активно работать над стабильностью работы сервиса, т.к. это все пользователи, чья активность снизилась, сталкивались с ошибками сервиса.
#
# Больше 70% пользователей из данного сегмента очень часто покупают товары именно по акции. Т.к. акции не постоянны, то и покупательская активность таких пользователей не постоянна. **Рекомендуется** чаще проводить акционные кампании для привлечения пользователей.
#
# Так же стоит отметить, что больше 76% пользователей, чья активность с большой вероятностью снизится, согласны на рассылку рекламы от сервиса. **Рекомендуется** активно рассылать рекламу по интересующей пользователя категории.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# В данном проекте была проделана следующая работа:
# 1. Загрузка и изучение данных - все данные успешно загружены;
# 2. Предобработка данных:
#   * Столбцы всех датафреймов приведены в единый стиль.
#   * Все дубликаты проверены:
#      * В датафрейме *`market_file`* найдены и исправлены неявные дубликаты.
#      * В датафрейме *`market_time`* найдены и исправлены ошибки в названии периода.
#      * В остальных датафреймах дубликатов не обнаружено.
#   * Во всех датафреймах проверены пропуски. Пропусков не обнаружено.
#   * Все выбросы проверены:
#      * В датафрейме *`market_money`* найдена аномалия в виде **выручки** в размере **106862.2**. Аномалия заменена на медианное значение выручки.
#      * В датафрейме *`market_money`* проверены выбросы в виде **нулевой выручки**. После проверки решено временно оставить, как есть.
# 3. Иследовательский анализ данных:
#   * Выявлен дисбаланс в таких признаках, как *`покупательская_активность`* и *`тип_сервиса`*.
#   * Распределение всех численных признаков выглядит нормально.
#   * Для дальнейшей работы были выбраны только активные пользователи путём удаления выбросов с нулевой выручкой.
# 4. Объединение таблиц;
#   * Таблицы успешно объеденины.
#   * Количество строк осталось прежним.
#   * Новых дубликатов и пропусков не обнаружено.
# 5. Корреляционный анализ:
#   * По матрице корреляции можно видеть:
#     * *`Покупательская активность`* имеет:
#     * <u>***Высокую связь***</u> с *`страниц_за_визит`*.
#     * <u>***Заметную связь***</u> с *`маркет_актив_6_мес`*, *`акционные_покупки`*, *`средний_просмотр_категории_за_визит`*, *`неоплаченные_продукты_штук_квартал`*, *`препредыдущий_месяц_выручка`*, *`предыдущий месяц_минут`* и *`текущий_месяц_минут`*.
#   * <u>***Корреляционная связь отсутствует***</u> с *`разрешить_сообщать`* и *`маркет_актив_тек_мес`*.
# 6. Использование пайплайнов:
#   * Лучшая модель получилась **LogisticRegression** с гиперпараметром **C=6**.
#   * Метрика **ROC-AUC** на тестовой выборке оказалась лучше, чем на тренировочной(**0.92 и 0.9**).
# 7. Анализ важности признаков:
#   * Самые важные признаки:
#     * *`средний_просмотр_категорий_за_визит`* - Чем выше значение, тем ниже вероятность того, что *`покупательская_активность`* снизится.
#     * *`тип_сервиса`* - Пользователи с *премиум* реже имеют сниженную *`покупательская_активность`*, чем со значением *стандарт*.
#     * *`страниц_за_визит`* - Чем выше значение, тем ниже вероятность того, что *`покупательская_активность`* снизится.
#     * *`предыдущий_месяц_минут`* - Чем выше значение, тем ниже вероятность того, что *`покупательская_активность`* снизится.
#     * *`неоплаченные_продукты_штук_квартал`* - Чем выше значение, тем выше вероятность того, что *`покупательская_активность`* снизится.
# 8. Сегментация покупателей:
#   * Покупательская активность снизится, если следующие показатели будут иметь такие значения:
#     * *`маркет_актив_6_мес`* ниже 4.
#     * *`акционные_покупки`* выше 0.8.
#     * *`средний_просмотр_категорий_за_визит`* ниже 4.
#     * *`страниц_за_визит`* ниже 7.
#
# Согласно поставленной задаче была выбрана и построена лучшая модель с вероятность правильных предсказаний более 90%. Так же поставлены пороги для сегментирования пользователей с высокой вероятностью снижения покупательской активности.
#
# <u>**Рекомендации**</u> по данному сегменту пользователей для уменьшения вероятности снижения покупательской активности пользователей:
# * активно работать над стабильностью работы сервиса, т.к. это все пользователи, чья активность снизилась, сталкивались с ошибками сервиса.
# * активно рассылать рекламу по интересующей пользователя категории.
