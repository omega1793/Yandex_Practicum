# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# Привет, меня зовут Александр Куимов. Я буду ревьюером твоего проекта. Ты можешь обращаться ко мне на "ты"😏 Надеюсь, тебя также не смутит, если я буду обращаться к тебе на "ты", но если это неудобно, обязательно скажи об этом!
#
# **Пожалуйста, не перемещай, не изменяй и не удаляй мои комментарии**, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Прошу реагировать на все мои комментарии, по которым ты вносишь правки в проект, своими комментариями по шаблону, показанному чуть ниже. На каждое мое замечание нужно отвечать комментарием студента в маркдаун ячейке **ниже моей. Это нужно, чтобы не создавалась путаница**.😉
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В случае, если решение на отдельном шаге является полностью правильным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> В случае, когда решение на отдельном шаге станет еще лучше, если внести небольшие коррективы.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#  В случае, когда решение на отдельном шаге требует существенной переработки и внесения правок. Напоминаю, что проект не может быть принят с первого раза, если ревью содержит комментарии, рекомендующие доработать шаги.
# </div>
#
#
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>👋:</b> В такой цветовой ячейке - образце я прошу тебя оставлять твои комментарии. **Обязательно сохрани в нем заголовок "Комментарий студента" в каждой твоей ячейке**. Если исправляешь проект во второй раз и далее, не забывай пожалуйста указывать номер итерации, например, "Комментарий студента 2". У меня к этому моменту уже появится нумерация в моих комментариях.
# </div>
#
# <br/>
#
# Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие и дам тебе возможность самому найти и исправить ее. На реальной работе твой руководитель будет поступать также, и я пытаюсь подготовить тебя именно к работе датасаентистом. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку!🤓
#
#    **Если у тебя будут возникают какие-то сложности, связанные с выполнением этого проекта**, то я смогу отвечать тебе на вопросы только в ходе ревью до 24 часов на основании соглашения об уровне услуг SLA (это может быть любое время суток, даже ночью), и к сожалению, каждые из таких ревью расходуют доступные иттерации (их всего 6).
# Лучшее решение в подобных случаях - обратиться за помощью к преподавателю по проектам в треде для получения оперативных консультаций. На всякий случай акцентирую, что преподаватель отвечает в тредах, а в личку не отвечает. В редких случаях может возникнуть ситуация, когда преподаватель не ответил вовремя, в таком случае рекомендую связаться с куратором для оперативного решения вопроса.
#
#    **Если у тебя будут возникают вопросы, которые не касаются проекта и моих комментариев в нем**, а касаются теории и спринта, то я смогу кратко тебе ответить, а подробнее на вопрос тебе ответит преподаватель и по запросу сможет подобрать материал адекватный текущему прогрессу курса (только нужно написать ему в тред) 🤓

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка" data-toc-modified-id="Подготовка-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка</a></span><ul class="toc-item"><li><span><a href="#Подготовка-к-работе" data-toc-modified-id="Подготовка-к-работе-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Подготовка к работе</a></span></li><li><span><a href="#Изучение-данных" data-toc-modified-id="Изучение-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Изучение данных</a></span></li><li><span><a href="#Ресемплирование" data-toc-modified-id="Ресемплирование-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Ресемплирование</a></span></li><li><span><a href="#Выводы-по-подготовке-данных" data-toc-modified-id="Выводы-по-подготовке-данных-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Выводы по подготовке данных</a></span></li></ul></li><li><span><a href="#Анализ" data-toc-modified-id="Анализ-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ</a></span><ul class="toc-item"><li><span><a href="#Визуализация-временного-ряда" data-toc-modified-id="Визуализация-временного-ряда-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Визуализация временного ряда</a></span></li><li><span><a href="#Тренды-и-сезонности-временного-ряда" data-toc-modified-id="Тренды-и-сезонности-временного-ряда-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Тренды и сезонности временного ряда</a></span></li></ul></li><li><span><a href="#Обучение" data-toc-modified-id="Обучение-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Обучение</a></span><ul class="toc-item"><li><span><a href="#Подготовка-к-обучению-моделей" data-toc-modified-id="Подготовка-к-обучению-моделей-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Подготовка к обучению моделей</a></span></li><li><span><a href="#Обучение-модели-LinearRegression" data-toc-modified-id="Обучение-модели-LinearRegression-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Обучение модели LinearRegression</a></span></li><li><span><a href="#Обучение-модели-RandomForestRegressor" data-toc-modified-id="Обучение-модели-RandomForestRegressor-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Обучение модели RandomForestRegressor</a></span></li><li><span><a href="#Обучение-модели-DecisionTreeRegressor" data-toc-modified-id="Обучение-модели-DecisionTreeRegressor-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Обучение модели DecisionTreeRegressor</a></span></li><li><span><a href="#Обучение-модели-CatBoost" data-toc-modified-id="Обучение-модели-CatBoost-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Обучение модели CatBoost</a></span></li><li><span><a href="#Обучение-модели-LightGBM" data-toc-modified-id="Обучение-модели-LightGBM-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Обучение модели LightGBM</a></span></li></ul></li><li><span><a href="#Тестирование" data-toc-modified-id="Тестирование-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Тестирование</a></span><ul class="toc-item"><li><span><a href="#Сравнение-и-выбор-лучшей-модели" data-toc-modified-id="Сравнение-и-выбор-лучшей-модели-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Сравнение и выбор лучшей модели</a></span></li><li><span><a href="#Проверка-RMSE-на-тестовой-выборке" data-toc-modified-id="Проверка-RMSE-на-тестовой-выборке-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Проверка RMSE на тестовой выборке</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-проверки" data-toc-modified-id="Чек-лист-проверки-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист проверки</a></span></li></ul></div>

# %% [markdown]
# #  Прогнозирование заказов такси

# %% [markdown]
# Компания «Чётенькое такси» собрала исторические данные о заказах такси в аэропортах. Чтобы привлекать больше водителей в период пиковой нагрузки, нужно спрогнозировать количество заказов такси на следующий час. Постройте модель для такого предсказания.
#
# Значение метрики *RMSE* на тестовой выборке должно быть не больше 48.
#
# Вам нужно:
#
# 1. Загрузить данные и выполнить их ресемплирование по одному часу.
# 2. Проанализировать данные.
# 3. Обучить разные модели с различными гиперпараметрами. Сделать тестовую выборку размером 10% от исходных данных.
# 4. Проверить данные на тестовой выборке и сделать выводы.
#
#
# Данные лежат в файле `taxi.csv`. Количество заказов находится в столбце `num_orders` (от англ. *number of orders*, «число заказов»).

# %% [markdown]
# ## Подготовка

# %% [markdown]
# ### Подготовка к работе

# %%
# Обновим библиотеки
# !pip install --upgrade scikit-learn==1.0

# Импортируем все необходимые нам библиотеки

import time
import warnings
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from sklearn.model_selection import train_test_split, GridSearchCV, TimeSeriesSplit

# %%
# Активируется по окончанию проекта
# Проигнорируем предупреждения о возможных изменения работы функций в будущих версиях в Pandas
warnings.filterwarnings("ignore")

# %%
# Зафиксируем константы
RANDOM_STATE = 42

# %%
# Объявляем функцию для изучения всей информации об датафрейме
def df_review(df):
    print('Краткое содержание датафрейма')
    display(df.head())
    print('='*100)    
    print('Информация о датафрейме')
    df.info()
    print('='*100)   
    print('Размер датафрейма:', df.shape)
    print('='*100)  
    print('Охарактеризация числовых данных датафрейма')
    display(df.describe().T)
    print('='*100)
    print('Гистограмма для всех числовых данных')
    df.hist(figsize=(10, 5), bins=24);
    plt.xlabel('Значения')
    plt.ylabel('Частота')
    plt.show()
    print('='*100)
    print('Количество явных дубликатов в датафрейте:', df.duplicated().sum())
    print('Количество пропусков в датафрейте:', '\n', df.isna().sum())
    
# Объявляем функцию декорирования графика
def decorate_plot(plt, title, xlabel = ' Дата', ylabel = 'Количество заказов'):
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.grid(True)

# Объявим функцию разделения временного ряда на тренд и сезонную компоненту
def drow_decomposed_data(data, suptitle):
    decomposed = seasonal_decompose(data)
    fig = plt.figure(figsize=(20, 20))
    # График тренда
    plt.subplot(311)
    decomposed.trend.plot(ax=plt.gca())
    decorate_plot(plt, 'Тренд')
    # График сезонности
    plt.subplot(312)
    decomposed.seasonal.plot(ax=plt.gca()) 
    decorate_plot(plt, 'Сезонность')
    # График остатков
    plt.subplot(313)
    decomposed.resid.plot(ax=plt.gca()) 
    decorate_plot(plt, 'Остаток')
    plt.tight_layout()
    fig.suptitle(suptitle)  
    plt.show()

# Объявим функцию добавления признаков перед обучением модели
def add_features(data, lags_count):
    data = df.copy()
    data['month'] = df.index.month
    data['day'] = df.index.day
    data['dayofweek'] = df.index.dayofweek
    data['hour'] = df.index.hour
    for i in range(1, lags_count + 1):
        data['lag_{}'.format(i)] = data['num_orders'].shift(i)  
    data['rolling_mean'] = data['num_orders'].shift().rolling(1).mean()    
    # Удаляем пропуски в лагах
    data = data.dropna()
    data = data.reset_index(drop=True)    
    return data

# Объявим функцию обучения модели
def fit_model(estimator, param_grid, X_train, y_train, X_test, y_test):
    model = GridSearchCV(estimator=estimator,
                         param_grid=param_grid,
                         n_jobs=-1,
                         cv=TimeSeriesSplit(n_splits=5),
                         scoring='neg_root_mean_squared_error'
                         )
    start_time = time.time()
    model.fit(X_train, y_train)
    train_time = time.time() - start_time
    best_rmse = abs(round(model.best_score_, 1))
    print(f'Лучшая RMSE: {best_rmse}')
    print(f'Параметры лучшей модели: {model.best_params_}')
    best_model = estimator.set_params(**model.best_params_)
    start_time = time.time()
    best_model.fit(X_train, y_train)
    predict_time = time.time() - start_time
    predict_train = best_model.predict(X_train)
    train_rmse = mean_squared_error(y_train, predict_train, squared=False)
    return best_model, best_rmse, train_time, predict_time, train_rmse

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# Отлично, что написана функция, которая возвращает новый датафрейм, а не изменяет глобальную переменную

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# Отлично, что применяется TimeSeriesSplit, а не простой сплиттер

# %%
# Загружаем данные с возможностью загрузить их с сервера в случае недоступности локальных файлов
try:
    df = pd.read_csv('/datasets/taxi.csv', index_col='datetime', parse_dates=[0])
except:
    df = pd.read_csv('https://code.s3.yandex.net/datasets/autos.csv', index_col='datetime', parse_dates=[0])

# %% [markdown]
# ### Изучение данных

# %%
# Изучаем датафрейм
df_review(df)
# Out:
# Краткое содержание датафрейма
#                      num_orders
# datetime
# 2018-03-01 00:00:00           9
# 2018-03-01 00:10:00          14
# 2018-03-01 00:20:00          28
# 2018-03-01 00:30:00          20
# 2018-03-01 00:40:00          32
# ...
# Информация о датафрейме
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 26496 entries, 2018-03-01 00:00:00 to 2018-08-31 23:50:00
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   num_orders  26496 non-null  int64
# dtypes: int64(1)
# memory usage: 414.0 KB
# ...
# Размер датафрейма: (26496, 1)
# ...
# Охарактеризация числовых данных датафрейма
#               count       mean      std  min  25%   50%   75%    max
# num_orders  26496.0  14.070463  9.21133  0.0  8.0  13.0  19.0  119.0
# ...
# Гистограмма для всех числовых данных
# ...
# Количество явных дубликатов в датафрейте: 26415
# Количество пропусков в датафрейте:
#  num_orders    0
# dtype: int64

# %%
# Проверяем уникальность индекса
id_unique = df.index.is_unique
print('Уникальность индекса датафрейма', id_unique)
# Out:
# Уникальность индекса датафрейма True

# %% [markdown]
# ### Ресемплирование

# %%
# Выполним ресемплирование по одному часу
df = df.resample('1H').sum()

# %%
# Проверим датафрейм
df.head()
# Out:
#                      num_orders
# datetime
# 2018-03-01 00:00:00         124
# 2018-03-01 01:00:00          85
# 2018-03-01 02:00:00          71
# 2018-03-01 03:00:00          66
# 2018-03-01 04:00:00          43

# %% [markdown]
# ### Выводы по подготовке данных

# %% [markdown]
# Во время подготовки данных была проделана следующая работа:
# * Подготовка к работе:
#   * Все библиотеки импортированы
#   * Константы зафиксированы
#   * Данные загружены
# * Изучение данных:
#   * Краткое содержание датафрейма проверено
#   * Информация о датафрейме проверена
#   * Размерность датафрейма проверена
#   * Числовые данные охарактеризованы
#   * Гистограмма данных построена
#   * Дубликаты проверены
#   * Пропуски проверены
#   * Уникальность индекса проверена
# * Ресемплирование данных проведено

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# С данными познакомились, проведен первичный аналитический осмотр!) Отлично, что проведено ресемплирование с использованием суммы. Полученная информация поможет нам в дальнейшем с предобработкой данных

# %% [markdown]
# ## Анализ

# %% [markdown]
# ### Визуализация временного ряда

# %%
# Рассчитываем скользящее среднее
df['rolling_mean'] = df.rolling(15).mean()

# Строим график со скользящим средним
plt.figure(figsize=(20, 8))
plt.plot(df['num_orders'], label='num_orders', color='blue')
plt.plot(df['rolling_mean'], label='rolling_mean', color='red')
plt.legend()
decorate_plot(plt, 'Количество заказов такси в час в течение полугода')
plt.show()

# %%
# Удаляем столбец со скользящим средним, так как он будет мешать при дальнейшем анализе
df = df.drop('rolling_mean', axis=1)

# %% [markdown]
# *По графику видно, что среднее количество заказов увеличивается со временем, значит можно предположить, что ряд не стационарный.*

# %% [markdown]
# ### Тренды и сезонности временного ряда

# %%
# Строим графики по всему временному ряду
drow_decomposed_data(df, 'Разложение временного ряда на составляющие за полгода')

# %%
drow_decomposed_data(df['2018-06-01':'2018-06-15'], 'Разложение временного ряда на составляющие за две недели')

# %%
drow_decomposed_data(df['2018-06-01':'2018-06-02'], 'Разложение временного ряда на составляющие за два дня')

# %% [markdown]
# *По графику замечается сезонность по часу на каждый день. Отресемплируем данные по дням и посмотрим на графики.*

# %%
# Ресемплирует данные по дням и сохраняем в отдельную переменную
df_res_day = df.resample('1D').sum()

# %%
drow_decomposed_data(df_res_day['2018-06-01':'2018-06-22'], 'Разложение временного ряда на составляющие за три недели с точностью до дня')

# %% [markdown]
# **Выводы по трендам и сезонности временного ряда:**
# * Сезонность периодична в течение суток. Самый большой всплеск увеличения заказов наблюдается в 12 часов ночи. В среднем имеются всплески увеличения заказов ночью, в обеденное время и вечером. Самый большой всплеск вероятно связан с тем, что общественный транспорт перестаёт работать в это время.
# * По ресемплированным данным по дням заметна сезонность по дням недели. Отсылаясь на календарь замечен всплеск заказов по понедельникам, средам, пятницам и субботам.
# * Тренд по общим данным можно назвать восходящим, т.к. в среднем заказы в час постепенно увеличились с 50 до 160.

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# Декомпозиция сделана верно. Хорошо, что сезонность была визуализирована на более коротком интервале)

# %% [markdown]
# ## Обучение

# %% [markdown]
# ### Подготовка к обучению моделей

# %%
# Создаём признаки
data = add_features(df, 10)

# %%
# Проверим датафрейм
data.head()
# Out:
#    num_orders  month  day  dayofweek  hour  lag_1  lag_2  lag_3  lag_4  lag_5  \
# 0          64      3    1          3    10   69.0   34.0   15.0   12.0    6.0
# 1          96      3    1          3    11   64.0   69.0   34.0   15.0   12.0
# 2          30      3    1          3    12   96.0   64.0   69.0   34.0   15.0
# 3          32      3    1          3    13   30.0   96.0   64.0   69.0   34.0
# 4          48      3    1          3    14   32.0   30.0   96.0   64.0   69.0
#
#    lag_6  lag_7  lag_8  lag_9  lag_10  rolling_mean
# 0   43.0   66.0   71.0   85.0   124.0          69.0
# 1    6.0   43.0   66.0   71.0    85.0          64.0
# 2   12.0    6.0   43.0   66.0    71.0          96.0
# 3   15.0   12.0    6.0   43.0    66.0          30.0
# 4   34.0   15.0   12.0    6.0    43.0          32.0

# %%
# Делим датафрейм на признаки и целевой признак
X = data.drop(['num_orders'], axis=1)
y = data['num_orders']

# %%
# Делим датафрейм на выборки
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=False, test_size=0.1, random_state=RANDOM_STATE)

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# Хорошо, что деление происходит последовательно по времени

# %%
# Посмотрим на размеры выборок
print('Размер датафрейма X_train:')
print(X_train.shape)

print('Размер датафрейма X_test:')
print(X_test.shape)

print('Размер датафрейма y_train:')
print(y_train.shape[0])

print('Размер датафрейма y_test:')
print(y_test.shape[0])
# Out:
# Размер датафрейма X_train:
# (3965, 15)
# Размер датафрейма X_test:
# (441, 15)
# Размер датафрейма y_train:
# 3965
# Размер датафрейма y_test:
# 441

# %%
# Создадим таблицу сравнения характеристик моделей
сomparison = pd.DataFrame(columns=['Модель', 'Время обучения', 'Время предсказания', 'тренировочная метрика RMSE'])

# %% [markdown]
# ### Обучение модели LinearRegression

# %%
best_model_LR, best_rmse, train_time, \
predict_time, train_rmse_LR = fit_model(LinearRegression(), 
            [{'fit_intercept': [True, False]},
             {'copy_X': [True, False]}, {'n_jobs': [1, -1]}], 
            X_train, y_train, X_test, y_test)

сomparison.loc[0] = ['LinearRegression', train_time, predict_time, train_rmse_LR]
# Out:
# Лучшая RMSE: 31.5
# Параметры лучшей модели: {'fit_intercept': False}

# %% [markdown]
# ### Обучение модели RandomForestRegressor

# %%
best_model_RFR, best_rmse, train_time, \
predict_time, train_rmse_RFR = fit_model(RandomForestRegressor(random_state=RANDOM_STATE), 
            {'n_estimators': range(50, 100, 10), 'max_depth': range(1, 11, 2)}, 
            X_train, y_train, X_test, y_test)

сomparison.loc[1] = ['RandomForestRegressor', train_time, predict_time, train_rmse_RFR]
# Out:
# Лучшая RMSE: 26.0
# Параметры лучшей модели: {'max_depth': 9, 'n_estimators': 80}

# %% [markdown]
# ### Обучение модели DecisionTreeRegressor

# %%
best_model_DTR, best_rmse, train_time, \
predict_time, train_rmse_DTR = fit_model(DecisionTreeRegressor(random_state=RANDOM_STATE),
            {'max_depth': range(1, 11, 2)}, 
            X_train, y_train, X_test, y_test)

сomparison.loc[2] = ['DecisionTreeRegressor', train_time, predict_time, train_rmse_DTR]
# Out:
# Лучшая RMSE: 31.0
# Параметры лучшей модели: {'max_depth': 7}

# %% [markdown]
# ### Обучение модели CatBoost

# %%
best_model_CB, best_rmse, train_time, \
predict_time, train_rmse_LR = fit_model(CatBoostRegressor(random_state=RANDOM_STATE, verbose=False), 
            {'depth': [4, 6, 8], 'learning_rate': [0.01, 0.1, 1]}, 
            X_train, y_train, X_test, y_test)

сomparison.loc[3] = ['CatBoost', train_time, predict_time, train_rmse_LR]
# Out:
# Лучшая RMSE: 25.4
# Параметры лучшей модели: {'depth': 6, 'learning_rate': 0.01}

# %% [markdown]
# ### Обучение модели LightGBM

# %%
best_model_LGBM, best_rmse, train_time, \
predict_time, train_rmse_LGBM = fit_model(LGBMRegressor(random_state=RANDOM_STATE), 
            {'n_estimators': [50, 100, 200], 'max_depth': [3, 5, 7]}, 
            X_train, y_train, X_test, y_test)

сomparison.loc[4] = ['LightGBM', train_time, predict_time, train_rmse_LGBM]
# Out:
# Лучшая RMSE: 25.0
# Параметры лучшей модели: {'max_depth': 5, 'n_estimators': 100}

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# Молодец, что пробуешь разные модели в этом шаге)
# </div>

# %% [markdown]
# ## Тестирование

# %% [markdown]
# ### Сравнение и выбор лучшей модели

# %%
# Посмотрим на таблицу характеристик моделей
сomparison
# Out:
#                   Модель  Время обучения  Время предсказания  \
# 0       LinearRegression        2.452145            0.093149
# 1  RandomForestRegressor       53.179155            1.404265
# 2  DecisionTreeRegressor        0.352770            0.021980
# 3               CatBoost      239.758677            3.859125
# 4               LightGBM       26.046248            0.508417
#
#    тренировочная метрика RMSE
# 0                   30.250096
# 1                   16.931612
# 2                   21.786395
# 3                   19.984256
# 4                   16.516069

# %% [markdown]
# По итогу самой быстрой моделью оказалась **DecisionTreeRegressor**. Лучшую метрику RMSE показала модель **LightGBM**.

# %% [markdown]
# Окончательным решением было принято выбрать модель градиентного бустинга **LightGBM**, как самый оптимальный вариант по времени обучения и предсказаний и по лучшему качеству предсказаний.

# %% [markdown]
# ### Проверка RMSE на тестовой выборке

# %%
# Проверяем модель на тестовой выборке
predictions_LightGBM = best_model_LGBM.predict(X_test)

# Считаем метрику RMSE на тренировочной выборке
test_rmse_LightGBM = mean_squared_error(y_test, predictions_LightGBM, squared=False)

print("RMSE модели на тестовой выборке: %.2f" % test_rmse_LightGBM)
# Out:
# RMSE модели на тестовой выборке: 42.49

# %% [markdown]
# **Модель LightGBM полностью подходит под требования заказчика!**👍

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# В конце проекта желательно визуализировать результаты (построить 2 временных ряда на одном графике), показать предсказанные значения лучшей модели и реальные тестовые

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Во время работы над проектом было сделано:
# * Подготовка:
#   * Подготовка к работе:
#       * Все библиотеки импортированы
#       * Константы зафиксированы
#       * Данные загружены
#   * Изучение данных:
#     * Краткое содержание датафрейма проверено
#     * Информация о датафрейме проверена
#     * Размерность датафрейма проверена
#     * Числовые данные охарактеризованы
#     * Гистограмма данных построена
#     * Дубликаты проверены
#     * Пропуски проверены
#     * Уникальность индекса проверена
#   * Ресемплирование данных проведено
# * Анализ:
#   * Скользящее среднее временного ряда проанализировано
#   * Тренд и сезонность временного ряда проанализированы
# * Обучение:
#   * Данные подготовлены к обучению моделей
#   * Обучено 5 видов моделей с подбором лучших гиперпараметров:
#     * LinearRegression
#     * RandomForestRegressor
#     * DecisionTreeRegressor
#     * CatBoost
#     * LightGBM
# * Тестирование:
#   * Все модели были охарактеризованы и проанализированы
#   * Лучшая модель выбрана - **LightGBM**
#   * Метрика RMSE лучшей модели на тестовой выборке проверена - **42.49**

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
#
# <h2> Итоговый комментарий ревьюера <a class="tocSkip"> </h2>
#
# У меня сложилось отличное общее впечатление о проекте, тебе удалось неплохо справиться с этим проектом. Молодец! Подготовлены данные для анализа, изучен каждый параметр. Все красиво визуализировано, построено несколько моделей регрессии и оценено их качество. Осмысленная аналитика и дельная модельная работа - многое удалось как надо)
#
# Отмечу отдельные положительные моменты проекта🙂:
#
# - в ходе проекта встречались функции, помогающие избавиться от дублирования кода;
# - много красивых визуализаций в проекте и хорошая интерпретация;
# - при обучении моделей использована валидация и поиск гиперпараметров.
#
# Принимаю работу)
#
# Если хочешь лучше разобраться в теме, то могу посоветовать тебе:
#
# Полезная лекция про временные ряды: https://www.youtube.com/watch?v=u433nrxdf5k
#
# Б.Б. Демешев - временные ряды https://disk.yandex.ru/i/LiDHB-B3A6Lz5A
#
# Базовое применение ARIMA - https://colab.research.google.com/drive/17RnG91Eq8JBKyxToNzvCvjibfxum-oPj?usp=sharing
#
# Канторович - Анализ временных рядов https://yadi.sk/i/IOkUOS3hTXf3gg
# https://facebook.github.io/prophet/
#
# https://facebook.github.io/prophet/docs/quick_start.html#python-api
#
# https://nbviewer.jupyter.org/github/miptgirl/habra_materials/blob/master/prophet/habra_data.ipynb
#
#
#
# В этом проекте были отработаны все моменты. Если у тебя остались вопросы, то можно обратиться ко мне через куратора или напрямую адресовать вопросы преподавателю в тред.
#
# Успехов тебе в следующем спринте!
#
# Рад был помочь тебе)
#
# **Буду очень благодарен, если ты поставишь мне положительную оценку за проект в форме на странице курса, это важно для меня. Достаточно поставить оценку, а комментарий можешь написать по желанию:)**
#
# </div>

# %% [markdown]
# ## Чек-лист проверки

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [x]  Весь код выполняется без ошибок
# - [x]  Ячейки с кодом расположены в порядке исполнения
# - [x]  Данные загружены и подготовлены
# - [x]  Данные проанализированы
# - [x]  Модель обучена, гиперпараметры подобраны
# - [x]  Качество моделей проверено, выводы сделаны
# - [x]  Значение *RMSE* на тестовой выборке не больше 48
